# %% [markdown]
# # Theoretical Questions on MongoDB and Databases
#
# ## 1. What are the key differences between SQL and NoSQL databases?
# SQL (Structured Query Language) databases and NoSQL (Not Only SQL) databases have fundamental differences:
#
# - **Structure:** SQL databases use a structured, tabular format, whereas NoSQL databases use flexible schema types like document, key-value, column-family, or graph.
# - **Scalability:** SQL databases typically scale vertically (adding more power to a single machine), while NoSQL databases scale horizontally (distributing data across multiple machines).
# - **Schema:** SQL databases require a predefined schema, whereas NoSQL databases have dynamic schemas.
# - **ACID Compliance:** SQL databases ensure ACID (Atomicity, Consistency, Isolation, Durability) properties, whereas NoSQL databases often prioritize high availability and partition tolerance over strong consistency.
# - **Use Cases:** SQL is best for complex queries and structured data, while NoSQL is ideal for large-scale, unstructured, or semi-structured data applications.
#
# ## 2. What makes MongoDB a good choice for modern applications?
# MongoDB is widely used in modern applications because of:
#
# - **Flexible Schema:** Allows storage of varied and evolving data structures.
# - **Scalability:** Uses horizontal scaling (sharding) to handle large data volumes efficiently.
# - **High Performance:** Optimized for read and write operations using indexes and memory-mapped storage.
# - **Replication & High Availability:** Supports automatic failover and redundancy through replica sets.
# - **JSON-Like Documents:** Stores data in BSON format, which is easy to work with in web applications.
# - **Powerful Aggregation Framework:** Enables complex queries, transformations, and real-time analytics.
#
# ## 3. Explain the concept of collections in MongoDB.
# In MongoDB, a **collection** is a group of documents that share a similar purpose, similar to a table in SQL databases. However, unlike tables, collections do not enforce a strict schema, meaning documents within a collection can have different fields and structures.
#
# Example:
# ```json
# {
#   "_id": 1,
#   "name": "John Doe",
#   "email": "johndoe@example.com",
#   "age": 30
# }

# %% [markdown]
# ## 4. How does MongoDB ensure high availability using replication?
#
# MongoDB ensures high availability using **replica sets**. A **replica set** is a group of MongoDB servers that maintain the same dataset.
#
# ### Components of a Replica Set:
# - **Primary Node:** Handles all write operations.
# - **Secondary Nodes:** Maintain copies of the primary node's data.
# - **Automatic Failover:** If the primary node fails, a secondary node is elected as the new primary.
# - **Read Scalability:** Secondary nodes can handle read queries to improve performance.
#
# ### Example:
# A replica set typically consists of three nodes:
# 1. **Primary:** Accepts writes and propagates changes.
# 2. **Secondary 1:** Synchronizes data from the primary.
# 3. **Secondary 2:** Also synchronizes data from the primary and can take over if the primary fails.
#
# Replication ensures data redundancy, system reliability, and automatic recovery from failures.
#
# ---
#
# ## 5. What are the main benefits of MongoDB Atlas?
#
# MongoDB Atlas is a cloud-based, fully managed database service that simplifies database deployment and management.
#
# ### Key Benefits:
# - **Automatic Scaling:** Adjusts database resources based on workload demand.
# - **Global Distribution:** Deploys data across multiple regions for redundancy and availability.
# - **Automated Backups:** Ensures data safety with periodic snapshots.
# - **Security Features:** Provides built-in encryption, access controls, and authentication.
# - **Monitoring & Performance Optimization:** Offers real-time monitoring tools and performance insights.
#
# MongoDB Atlas eliminates operational overhead and allows developers to focus on building applications rather than managing databases.
#
# ---
#
# ## 6. What is the role of indexes in MongoDB, and how do they improve performance?
#
# Indexes in MongoDB enhance query performance by allowing the database to quickly locate documents without scanning the entire collection.
#
# ### Benefits of Indexes:
# - **Faster Queries:** Reduces query execution time.
# - **Efficient Sorting:** Improves sorting operations.
# - **Reduced Resource Usage:** Lowers CPU and memory consumption.
#
# ### Types of Indexes:
# 1. **Single-field Indexes:** Optimized for queries on one field.
# 2. **Compound Indexes:** Indexes multiple fields to optimize complex queries.
# 3. **Multikey Indexes:** Indexes array fields.
# 4. **Text Indexes:** Used for full-text search.
# 5. **Geospatial Indexes:** Supports location-based queries.
#
# ### Example:
# Creating an index on the `email` field to speed up searches:
# ```javascript
# db.users.createIndex({ "email": 1 });

# %% [markdown]
# ## 7. Describe the stages of the MongoDB aggregation pipeline.
#
# The **aggregation pipeline** is a framework for data processing and transformation in MongoDB. It consists of multiple stages that allow complex data manipulation.
#
# ### **Key Stages:**
# 1. **$match:** Filters documents based on specified criteria.
# 2. **$group:** Groups documents and performs aggregations like sum, count, average, etc.
# 3. **$project:** Reshapes documents by including, excluding, or modifying fields.
# 4. **$sort:** Sorts documents based on one or more fields.
# 5. **$limit:** Restricts the number of documents returned.
# 6. **$lookup:** Performs a join operation with another collection.
# 7. **$unwind:** Deconstructs an array field into separate documents.
#
# ### **Example Usage:**
# Retrieving the top customers based on their total spending:
# ```javascript
# db.orders.aggregate([
#   { $match: { status: "delivered" } },
#   { $group: { _id: "$customerId", totalSpent: { $sum: "$amount" } } },
#   { $sort: { totalSpent: -1 } },
#   { $limit: 5 }
# ]);

# %% [markdown]
# ## 8. What is sharding in MongoDB? How does it differ from replication?
#
# ### **Sharding:**
# Sharding is a technique used in MongoDB for **horizontal scaling**, where data is distributed across multiple servers (shards). It helps improve performance and handles large datasets efficiently.
#
# ### **Difference Between Sharding and Replication:**
# | Feature       | Sharding | Replication |
# |--------------|----------|------------|
# | Purpose      | Improves performance and scalability | Provides data redundancy and availability |
# | Data Storage | Data is partitioned across multiple servers | Each node holds the same data as the primary node |
# | Write Scaling | Supports write scalability | No write scalability |
# | Read Scaling | Queries are distributed across shards | Reads can be performed from secondary nodes |
#
# ### **Components of Sharding:**
# 1. **Shard Servers:** Store distributed portions of the dataset.
# 2. **Config Servers:** Maintain metadata and mapping of shards.
# 3. **Query Router (mongos):** Routes client queries to the appropriate shard.
#
# ### **Example of Enabling Sharding:**
# ```javascript
# sh.enableSharding("myDatabase")

# %% [markdown]
# ## 9. What is PyMongo, and why is it used?
#
# ### **What is PyMongo?**
# **PyMongo** is the official Python driver for MongoDB, allowing Python applications to interact with MongoDB databases.
#
# ### **Why Use PyMongo?**
# - Provides an easy interface for performing database operations like insert, update, delete, and query.
# - Supports indexing, aggregation, and transactions.
# - Integrates with Python web frameworks like Flask and Django.
# - Enables developers to work with MongoDB directly using Python.
#
# ### **Basic Usage Example:**
# Connecting to MongoDB and inserting a document using PyMongo:
# ```python
# from pymongo import MongoClient
#
# # Connect to MongoDB
# client = MongoClient("mongodb://localhost:27017/")
#
# # Select database and collection
# db = client["mydatabase"]
# collection = db["users"]
#
# # Insert a document
# collection.insert_one({"name": "Alice", "age": 25})
#
# # Find a document
# user = collection.find_one({"name": "Alice"})
# print(user)

# %% [markdown]
# ## 10. What are the ACID properties in the context of MongoDB transactions?
#
# ### **What are ACID Properties?**
# ACID stands for **Atomicity, Consistency, Isolation, and Durability**. These properties ensure reliable and secure database transactions.
#
# ### **ACID Properties in MongoDB:**
# 1. **Atomicity:**
#    - Ensures that a transaction is **all or nothing**—if one operation fails, the entire transaction is rolled back.
#    - Example: Updating multiple documents within a transaction will either succeed completely or fail entirely.
#
# 2. **Consistency:**
#    - Guarantees that the database remains in a valid state before and after a transaction.
#    - Ensures that constraints (such as unique fields) are maintained.
#
# 3. **Isolation:**
#    - Transactions run independently without interfering with each other.
#    - Prevents issues like dirty reads and non-repeatable reads.
#
# 4. **Durability:**
#    - Once a transaction is committed, the changes are permanently stored in the database, even in case of a system failure.
#
# ### **MongoDB Transactions:**
# - Introduced in MongoDB **4.0** for replica sets and **4.2** for sharded clusters.
# - Support multi-document transactions.
# - Use the `start_session()` method to implement transactions.

# %% [markdown]
# ## 11. What is the purpose of MongoDB’s `explain()` function?
#
# ### **What is `explain()`?**
# The `explain()` function in MongoDB provides detailed execution statistics for a query, helping developers **analyze and optimize query performance**.
#
# ### **Why Use `explain()`?**
# - Helps understand how MongoDB executes a query.
# - Identifies whether an index is being used.
# - Analyzes query execution time and resource usage.
# - Helps detect performance bottlenecks.
#
# ### **Modes of `explain()` Output:**
# MongoDB provides different execution modes for `explain()`:
#
# 1. **"queryPlanner"** (default mode)
#    - Shows the execution plan without running the query.
# 2. **"executionStats"**
#    - Executes the query and provides runtime statistics.
# 3. **"allPlansExecution"**
#    - Provides detailed statistics for all considered query plans.

# %% [markdown]
# ## 12. How does MongoDB handle schema validation?
#
# MongoDB allows schema validation using **JSON Schema** to enforce rules on document structure within a collection.
#
# ### **Key Features of Schema Validation:**
# - Ensures data integrity by defining required fields, data types, and constraints.
# - Can be applied at the collection level.
# - Supports operators like `$jsonSchema`, `$type`, `$required`, `$enum`, and more.

# %% [markdown]
# ## 13. What is the difference between a primary and a secondary node in a replica set?
#
# ### **Primary Node:**
# - The primary node in a replica set is responsible for handling all **write operations**.
# - It also handles **read operations** by default, unless configured otherwise.
# - The primary node replicates its data to the secondary nodes to ensure data redundancy and availability.
# - If the primary node fails, one of the secondary nodes is elected as the new primary.
#
# ### **Secondary Node:**
# - Secondary nodes are copies of the primary node and hold the same data.
# - They **replicate** data from the primary node but do not handle write operations.
# - Secondary nodes can be configured to handle **read operations** (using `readPreference`).
# - They are used to provide **fault tolerance** and **read scalability** by distributing read requests across the secondary nodes.
#
# ### **Key Differences:**
# | Feature          | Primary Node               | Secondary Node           |
# |------------------|----------------------------|--------------------------|
# | **Write Operations** | Allowed                   | Not allowed              |
# | **Read Operations**  | Default (unless configured) | Can be configured via `readPreference` |
# | **Data Replication** | Replicates data to secondaries | Replicates data from primary |
# | **Role in Failover**  | Can be replaced if fails | Can become primary in case of failure |
# | **Data Updates**    | Writes data               | Syncs data from primary |

# %% [markdown]
# ## 14. What security mechanisms does MongoDB provide for data protection?
#
# MongoDB offers several security mechanisms to ensure data protection and secure database operations:
#
# ### **1. Authentication & Authorization**
# - **Authentication** ensures that only authorized users can access MongoDB.
# - MongoDB uses **role-based access control (RBAC)** to define user roles and permissions.
# - MongoDB supports **SCRAM** (Salted Challenge Response Authentication Mechanism) as the default authentication method.
#
# ### **2. Transport Layer Security (TLS/SSL)**
# - MongoDB supports **TLS/SSL encryption** to secure data transmission between clients and servers.
# - Ensures that data is encrypted while in transit, preventing man-in-the-middle attacks.
#
# ### **3. Data Encryption**
# - **Encryption at Rest** protects data stored on disk, ensuring it is encrypted and inaccessible without proper authorization.
# - MongoDB Enterprise Edition provides **field-level encryption**, allowing sensitive data to be encrypted within the database itself.
#
# ### **4. Network Security**
# - **IP Whitelisting** restricts access to MongoDB from specific IP addresses, enhancing the security of the network.
# - MongoDB can be configured to restrict database access based on specific network rules.
#
# ### **5. Auditing**
# - MongoDB supports **auditing** to track database operations for compliance, regulatory, and monitoring purposes.
# - The auditing feature logs important operations such as login attempts, access to sensitive data, and changes to database settings.
#
# These mechanisms ensure that MongoDB is protected from unauthorized access, data breaches, and other security threats, providing robust data protection in both on-premise and cloud environments.

# %% [markdown]
# ## 15. Explain the concept of embedded documents and when they should be used.
#
# ### **What Are Embedded Documents?**
# Embedded documents, also known as **nested documents**, are documents that are stored inside another document. MongoDB allows for the storage of these embedded documents within a parent document, which can help reduce the need for joins.
#
# ### **Advantages of Embedded Documents:**
# - **Faster Reads:** Retrieving all related data in a single query without needing to perform joins or multiple queries.
# - **Atomic Updates:** Ensures consistency when updating related data within the same document.
# - **Simplified Data Structure:** Avoids the need for complex relationships and referencing data across collections.
#
# ### **When to Use Embedded Documents:**
# - **One-to-few relationships:** Use embedded documents when the relationship between data is one-to-few (e.g., a user’s address or orders).
# - **Data that doesn’t change independently:** If the embedded data is unlikely to change or is mostly accessed together with the parent data.
# - **When performance is a priority:** Embedded documents reduce the need for joins and make read operations faster by keeping related data together in one place.
#
# ### **When Not to Use Embedded Documents:**
# - **Large or growing data:** Avoid embedding data that can grow significantly, such as lists with many entries, as it can lead to performance issues.
# - **Frequent independent updates:** If embedded data is frequently updated independently, it might be better to use **referencing** rather than embedding to avoid complications with large documents.

# %% [markdown]
# ## 16. What is the purpose of MongoDB’s `$lookup` stage in aggregation?
#
# ### **What is `$lookup`?**
# The `$lookup` stage in MongoDB’s **aggregation pipeline** allows you to perform a **join** operation between two collections. It is used to combine data from multiple collections based on a specified relationship, similar to SQL joins.
#
# ### **Purpose of `$lookup`:**
# - **Joins Collections:** Allows you to combine documents from two collections based on a common field.
# - **Optimizes Queries:** Helps in situations where you need to retrieve related data that exists in a different collection, reducing the need for multiple queries.
# - **Improves Data Retrieval:** Simplifies data retrieval and enables complex data analysis by combining data from different sources.
#
# ### **Common Use Cases for `$lookup`:**
# - Retrieving related data from multiple collections.
# - Performing operations like aggregating information across different documents.
# - Simplifying complex data queries by eliminating the need for application-side joins.
#
# The `$lookup` stage is particularly useful when working with **relational** data or when multiple collections need to be combined to get a complete dataset.

# %% [markdown]
# ## 17. What are some common use cases for MongoDB?
#
# MongoDB is a popular NoSQL database and is used in various scenarios, particularly when dealing with large volumes of unstructured or semi-structured data. Some common use cases include:
#
# - **Content Management Systems (CMS):** Flexible data models for storing articles, blog posts, and media content.
# - **Real-Time Analytics:** Processing large volumes of data and generating real-time insights.
# - **Mobile Applications:** Storing user data, including interactions and preferences, which can evolve over time.
# - **IoT (Internet of Things):** Handling large streams of data from connected devices, often in real-time.
# - **E-commerce Platforms:** Managing product catalogs, customer information, and transactions.
# - **Social Media Applications:** Storing user profiles, posts, and social interactions like comments and likes.
# - **Big Data and Data Warehousing:** MongoDB’s ability to scale horizontally makes it suitable for big data processing and storage.
#
# ## 18. What are the advantages of using MongoDB for horizontal scaling?
#
# MongoDB provides several advantages when it comes to **horizontal scaling** (distributing data across multiple servers):
#
# - **Sharding:** MongoDB uses **sharding** to split data across multiple servers (shards), allowing it to scale out and handle large datasets without impacting performance.
# - **Automatic Balancing:** The system automatically balances data across shards to ensure even distribution and avoid hotspots.
# - **High Availability:** MongoDB ensures high availability using **replica sets** that replicate data across multiple nodes, providing redundancy and failover.
# - **Elastic Scalability:** MongoDB can scale horizontally by adding more nodes to the cluster as data grows, without requiring downtime.
# - **Fault Tolerance:** If one server fails, data is still available from other shards and replica sets, ensuring continuous access to data.
#
# ## 19. How do MongoDB transactions differ from SQL transactions?
#
# MongoDB transactions provide atomicity and consistency across multiple documents, similar to SQL transactions, but with key differences:
#
# - **Multi-Document Transactions:**
#   - MongoDB supports **multi-document transactions**, which allow you to perform operations on multiple documents within a single transaction.
#   - SQL transactions typically work within a single table, while MongoDB allows you to update multiple collections in one atomic operation.
#
# - **ACID Compliance:**
#   - Both MongoDB and SQL transactions follow the **ACID** (Atomicity, Consistency, Isolation, Durability) properties, but MongoDB added support for multi-document ACID transactions starting in version **4.0**.
#
# - **Default Isolation Level:**
#   - SQL databases typically use a **serializable** isolation level by default.
#   - MongoDB uses **read committed** isolation by default, which ensures that only committed data is visible to transactions.
#
# - **Transaction Scope:**
#   - In SQL, transactions are usually confined to a single database and may involve multiple tables.
#   - MongoDB transactions can span multiple collections and databases, giving it more flexibility.
#
# ## 20. What are the main differences between capped collections and regular collections?
#
# Capped collections are special collections in MongoDB with a fixed size and an insertion order guarantee. The main differences between capped and regular collections are:
#
# - **Size Limitation:**
#   - **Capped Collections:** Have a maximum size and automatically remove the oldest documents when the size limit is reached.
#   - **Regular Collections:** Do not have a size limit and can grow indefinitely.
#
# - **Document Order:**
#   - **Capped Collections:** Preserve the insertion order and are optimized for **high-throughput** insert operations.
#   - **Regular Collections:** Do not guarantee any specific order for documents.
#
# - **Data Retention:**
#   - **Capped Collections:** The oldest documents are overwritten when the collection reaches its size limit.
#   - **Regular Collections:** Data is retained indefinitely unless explicitly deleted.
#
# - **Indexes:**
#   - **Capped Collections:** Automatically index on the `_id` field.
#   - **Regular Collections:** Can have custom indexes created by the user.
#
# - **Use Cases:**
#   - **Capped Collections:** Best for use cases that require storing logs, time-series data, or other scenarios where data retention is not required beyond a certain point.
#   - **Regular Collections:** Used for general-purpose data storage.
#
# ## 21. What is the purpose of the $match stage in MongoDB’s aggregation pipeline?
#
# The **`$match`** stage in MongoDB’s **aggregation pipeline** filters documents based on specified conditions. It is used to:
#
# - **Filter Data Early:** Helps reduce the dataset by limiting the number of documents that are passed to subsequent stages in the pipeline, improving performance.
# - **Apply Query Conditions:** It uses the same syntax as the `find()` method to filter documents.
# - **Match Specific Criteria:** It can filter documents based on field values, ranges, logical operators, and regular expressions.
#
# ### Common Use Cases for `$match`:
# - Filtering documents based on specific field values (e.g., find all documents where `status` is "active").
# - Combining `$match` with other stages like `$group` to refine the data before performing aggregation operations.
#
# The `$match` stage acts as a filter and is often one of the first stages in an aggregation pipeline to optimize query performance by reducing the number of documents that need to be processed.

# %% [markdown]
# ## 22. How can you secure access to a MongoDB database?
#
# Securing access to a MongoDB database is crucial to protect data from unauthorized access and potential breaches. MongoDB provides several mechanisms to secure access:
#
# ### **1. Authentication**
# - **Enable Authentication:** By default, MongoDB does not require authentication. To secure your MongoDB instance, enable authentication by setting up user credentials.
# - **SCRAM (Salted Challenge Response Authentication Mechanism):** MongoDB uses SCRAM for authentication by default, which hashes passwords to prevent password leakage.
#
# ### **2. Role-Based Access Control (RBAC)**
# - **User Roles:** MongoDB uses RBAC to assign roles to users based on what actions they can perform (e.g., read, write, admin).
# - **Custom Roles:** You can create custom roles tailored to the specific needs of users.
#
# ### **3. Authorization**
# - Use **built-in roles** or create **custom roles** that grant specific privileges (e.g., read-only access, read-write access).
#
# ### **4. Transport Layer Security (TLS/SSL)**
# - **Encryption in Transit:** Enable TLS/SSL encryption to secure communications between MongoDB clients and servers, preventing man-in-the-middle attacks.
#
# ### **5. Encryption**
# - **Encryption at Rest:** Ensure that data stored in the database is encrypted by using **MongoDB Enterprise Edition** to provide encryption at rest for sensitive data.
# - **Field-Level Encryption:** Use field-level encryption to encrypt sensitive data directly within the database.
#
# ### **6. IP Whitelisting and Firewall Configuration**
# - **IP Whitelisting:** Restrict database access to trusted IP addresses and networks.
# - **Firewall Rules:** Configure firewalls to limit access to MongoDB instances to specific IPs or ranges.
#
# ### **7. Auditing**
# - MongoDB supports **auditing** features, enabling tracking of sensitive database operations, such as authentication attempts and data access.
#
# By using these security measures, you can ensure that your MongoDB instance is protected from unauthorized access and vulnerabilities.
#
# ---
#
# ## 23. What is MongoDB’s WiredTiger storage engine, and why is it important?
#
# ### **What is WiredTiger?**
# **WiredTiger** is the default **storage engine** in MongoDB since version 3.2. It is designed to provide high performance and efficient use of resources. WiredTiger uses **document-level concurrency control** and is optimized for **high-throughput, low-latency performance**.
#
# ### **Key Features of WiredTiger:**
# 1. **Document-Level Concurrency Control:**
#    - Allows multiple operations to occur simultaneously on different documents without locking the entire collection, improving write performance and reducing contention.
#
# 2. **Compression:**
#    - WiredTiger provides built-in compression to reduce the storage footprint of data. It supports **snappy compression** by default and **zlib** compression as an option.
#    - This compression significantly reduces disk space usage without compromising performance.
#
# 3. **Write-Ahead Logging (WAL):**
#    - WiredTiger uses write-ahead logging, which provides durability and helps ensure that data is not lost in the event of a crash.
#
# 4. **Support for Multi-Version Concurrency Control (MVCC):**
#    - It uses MVCC to allow read and write operations to occur simultaneously without blocking each other, enhancing database performance under heavy load.
#
# 5. **High-Performance Data Access:**
#    - WiredTiger supports fast in-memory data access and efficient storage of large data sets.
#
# 6. **Transactions Support:**
#    - Starting with MongoDB 4.0, WiredTiger supports **multi-document transactions**, providing ACID guarantees across multiple documents, collections, and databases.
#
# ### **Why is WiredTiger Important?**
# - **Improved Performance:** It is optimized for modern hardware, enabling faster read/write operations, especially under heavy workloads.
# - **Better Resource Utilization:** It reduces disk space usage through compression and allows more efficient use of memory and CPU.
# - **Supports Modern Features:** WiredTiger supports critical features such as multi-document ACID transactions and document-level concurrency control, making it ideal for mission-critical applications.
# - **Scalability:** Its performance characteristics allow MongoDB to scale more effectively as data volume and application demands grow.
#
# WiredTiger is an essential component of MongoDB, ensuring that the database engine can handle modern workloads and provide high availability, performance, and scalability.

# %% [markdown]
# # Practical Questions

# %%
import pandas as pd

file_path = r"C:\Users\hetvi\Downloads\superstore.csv"  

superstore_df = pd.read_csv(file_path, encoding='ISO-8859-1')

superstore_df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
import pandas as pd
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017/")  
db = client["superstore"]  
orders_collection = db["orders"]

# %% [markdown]
# ## 1) Load the Superstore dataset from a CSV file into MongoDB

# %%
file_path = r"C:\Users\hetvi\Downloads\superstore.csv"  
superstore_df = pd.read_csv(file_path, encoding='ISO-8859-1')  

data = superstore_df.to_dict(orient="records")
orders_collection.insert_many(data)

print("Data inserted into MongoDB.")
# Out:
# Data inserted into MongoDB.

# %% [markdown]
# ## 2) Retrieve and print all documents from the Orders collection

# %%
all_orders = orders_collection.find()

for order in all_orders:
    print(order)
# Out:
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef1d'), 'Row ID': 1, 'Order ID': 'CA-2016-152156', 'Order Date': '11/8/2016', 'Ship Date': '11/11/2016', 'Ship Mode': 'Second Class', 'Customer ID': 'CG-12520', 'Customer Name': 'Claire Gute', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Henderson', 'State': 'Kentucky', 'Postal Code': 42420, 'Region': 'South', 'Product ID': 'FUR-BO-10001798', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Bush Somerset Collection Bookcase', 'Sales': 261.96, 'Quantity': 2, 'Discount': 0.0, 'Profit': 41.9136}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef1e'), 'Row ID': 2, 'Order ID': 'CA-2016-152156', 'Order Date': '11/8/2016', 'Ship Date': '11/11/2016', 'Ship Mode': 'Second Class', 'Customer ID': 'CG-12520', 'Customer Name': 'Claire Gute', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Henderson', 'State': 'Kentucky', 'Postal Code': 42420, 'Region': 'South', 'Product ID': 'FUR-CH-10000454', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back', 'Sales': 731.94, 'Quantity': 3, 'Discount': 0.0, 'Profit': 219.582}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef1f'), 'Row ID': 3, 'Order ID': 'CA-2016-138688', 'Order Date': '6/12/2016', 'Ship Date': '6/16/2016', 'Ship Mode': 'Second Class', 'Customer ID': 'DV-13045', 'Customer Name': 'Darrin Van Huff', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90036, 'Region': 'West', 'Product ID': 'OFF-LA-10000240', 'Category': 'Office Supplies', 'Sub-Category': 'Labels', 'Product Name': 'Self-Adhesive Address Labels for Typewriters by Universal', 'Sales': 14.62, 'Quantity': 2, 'Discount': 0.0, 'Profit': 6.8714}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef20'), 'Row ID': 4, 'Order ID': 'US-2015-108966', 'Order Date': '10/11/2015', 'Ship Date': '10/18/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'SO-20335', 'Customer Name': "Sean O'Donnell", 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Fort Lauderdale', 'State': 'Florida', 'Postal Code': 33311, 'Region': 'South', 'Product ID': 'FUR-TA-10000577', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bretford CR4500 Series Slim Rectangular Table', 'Sales': 957.5775, 'Quantity': 5, 'Discount': 0.45, 'Profit': -383.031}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef21'), 'Row ID': 5, 'Order ID': 'US-2015-108966', 'Order Date': '10/11/2015', 'Ship Date': '10/18/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'SO-20335', 'Customer Name': "Sean O'Donnell", 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Fort Lauderdale', 'State': 'Florida', 'Postal Code': 33311, 'Region': 'South', 'Product ID': 'OFF-ST-10000760', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': "Eldon Fold 'N Roll Cart System", 'Sales': 22.368, 'Quantity': 2, 'Discount': 0.2, 'Profit': 2.5164}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef22'), 'Row ID': 6, 'Order ID': 'CA-2014-115812', 'Order Date': '6/9/2014', 'Ship Date': '6/14/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'FUR-FU-10001487', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Eldon Expressions Wood and Plastic Desk Accessories, Cherry Wood', 'Sales': 48.86, 'Quantity': 7, 'Discount': 0.0, 'Profit': 14.1694}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef23'), 'Row ID': 7, 'Order ID': 'CA-2014-115812', 'Order Date': '6/9/2014', 'Ship Date': '6/14/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'OFF-AR-10002833', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Newell 322', 'Sales': 7.28, 'Quantity': 4, 'Discount': 0.0, 'Profit': 1.9656}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef24'), 'Row ID': 8, 'Order ID': 'CA-2014-115812', 'Order Date': '6/9/2014', 'Ship Date': '6/14/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'TEC-PH-10002275', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Mitel 5320 IP Phone VoIP phone', 'Sales': 907.152, 'Quantity': 6, 'Discount': 0.2, 'Profit': 90.7152}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef25'), 'Row ID': 9, 'Order ID': 'CA-2014-115812', 'Order Date': '6/9/2014', 'Ship Date': '6/14/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'OFF-BI-10003910', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'DXL Angle-View Binders with Locking Rings by Samsill', 'Sales': 18.504, 'Quantity': 3, 'Discount': 0.2, 'Profit': 5.7825}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef26'), 'Row ID': 10, 'Order ID': 'CA-2014-115812', 'Order Date': '6/9/2014', 'Ship Date': '6/14/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'OFF-AP-10002892', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': 'Belkin F5C206VTEL 6 Outlet Surge', 'Sales': 114.9, 'Quantity': 5, 'Discount': 0.0, 'Profit': 34.47}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef27'), 'Row ID': 11, 'Order ID': 'CA-2014-115812', 'Order Date': '6/9/2014', 'Ship Date': '6/14/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'FUR-TA-10001539', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Chromcraft Rectangular Conference Tables', 'Sales': 1706.184, 'Quantity': 9, 'Discount': 0.2, 'Profit': 85.3092}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef28'), 'Row ID': 12, 'Order ID': 'CA-2014-115812', 'Order Date': '6/9/2014', 'Ship Date': '6/14/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'TEC-PH-10002033', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Konftel 250 Conference\xa0phone\xa0- Charcoal black', 'Sales': 911.424, 'Quantity': 4, 'Discount': 0.2, 'Profit': 68.3568}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef29'), 'Row ID': 13, 'Order ID': 'CA-2017-114412', 'Order Date': '4/15/2017', 'Ship Date': '4/20/2017', 'Ship Mode': 'Standard Class', 'Customer ID': 'AA-10480', 'Customer Name': 'Andrew Allen', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Concord', 'State': 'North Carolina', 'Postal Code': 28027, 'Region': 'South', 'Product ID': 'OFF-PA-10002365', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Xerox 1967', 'Sales': 15.552, 'Quantity': 3, 'Discount': 0.2, 'Profit': 5.4432}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef2a'), 'Row ID': 14, 'Order ID': 'CA-2016-161389', 'Order Date': '12/5/2016', 'Ship Date': '12/10/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'IM-15070', 'Customer Name': 'Irene Maddox', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal Code': 98103, 'Region': 'West', 'Product ID': 'OFF-BI-10003656', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Fellowes PB200 Plastic Comb Binding Machine', 'Sales': 407.976, 'Quantity': 3, 'Discount': 0.2, 'Profit': 132.5922}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef2b'), 'Row ID': 15, 'Order ID': 'US-2015-118983', 'Order Date': '11/22/2015', 'Ship Date': '11/26/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'HP-14815', 'Customer Name': 'Harold Pawlan', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Fort Worth', 'State': 'Texas', 'Postal Code': 76106, 'Region': 'Central', 'Product ID': 'OFF-AP-10002311', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': 'Holmes Replacement Filter for HEPA Air Cleaner, Very Large Room, HEPA Filter', 'Sales': 68.81, 'Quantity': 5, 'Discount': 0.8, 'Profit': -123.858}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef2c'), 'Row ID': 16, 'Order ID': 'US-2015-118983', 'Order Date': '11/22/2015', 'Ship Date': '11/26/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'HP-14815', 'Customer Name': 'Harold Pawlan', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Fort Worth', 'State': 'Texas', 'Postal Code': 76106, 'Region': 'Central', 'Product ID': 'OFF-BI-10000756', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Storex DuraTech Recycled Plastic Frosted Binders', 'Sales': 2.544, 'Quantity': 3, 'Discount': 0.8, 'Profit': -3.816}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef2d'), 'Row ID': 17, 'Order ID': 'CA-2014-105893', 'Order Date': '11/11/2014', 'Ship Date': '11/18/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'PK-19075', 'Customer Name': 'Pete Kriz', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Madison', 'State': 'Wisconsin', 'Postal Code': 53711, 'Region': 'Central', 'Product ID': 'OFF-ST-10004186', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Stur-D-Stor Shelving, Vertical 5-Shelf: 72"H x 36"W x 18 1/2"D', 'Sales': 665.88, 'Quantity': 6, 'Discount': 0.0, 'Profit': 13.3176}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef2e'), 'Row ID': 18, 'Order ID': 'CA-2014-167164', 'Order Date': '5/13/2014', 'Ship Date': '5/15/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'AG-10270', 'Customer Name': 'Alejandro Grove', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'West Jordan', 'State': 'Utah', 'Postal Code': 84084, 'Region': 'West', 'Product ID': 'OFF-ST-10000107', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Fellowes Super Stor/Drawer', 'Sales': 55.5, 'Quantity': 2, 'Discount': 0.0, 'Profit': 9.99}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef2f'), 'Row ID': 19, 'Order ID': 'CA-2014-143336', 'Order Date': '8/27/2014', 'Ship Date': '9/1/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'ZD-21925', 'Customer Name': 'Zuschuss Donatelli', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94109, 'Region': 'West', 'Product ID': 'OFF-AR-10003056', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Newell 341', 'Sales': 8.56, 'Quantity': 2, 'Discount': 0.0, 'Profit': 2.4824}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef30'), 'Row ID': 20, 'Order ID': 'CA-2014-143336', 'Order Date': '8/27/2014', 'Ship Date': '9/1/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'ZD-21925', 'Customer Name': 'Zuschuss Donatelli', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94109, 'Region': 'West', 'Product ID': 'TEC-PH-10001949', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Cisco SPA 501G IP Phone', 'Sales': 213.48, 'Quantity': 3, 'Discount': 0.2, 'Profit': 16.011}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef31'), 'Row ID': 21, 'Order ID': 'CA-2014-143336', 'Order Date': '8/27/2014', 'Ship Date': '9/1/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'ZD-21925', 'Customer Name': 'Zuschuss Donatelli', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94109, 'Region': 'West', 'Product ID': 'OFF-BI-10002215', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Wilson Jones Hanging View Binder, White, 1"', 'Sales': 22.72, 'Quantity': 4, 'Discount': 0.2, 'Profit': 7.384}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef32'), 'Row ID': 22, 'Order ID': 'CA-2016-137330', 'Order Date': '12/9/2016', 'Ship Date': '12/13/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'KB-16585', 'Customer Name': 'Ken Black', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Fremont', 'State': 'Nebraska', 'Postal Code': 68025, 'Region': 'Central', 'Product ID': 'OFF-AR-10000246', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Newell 318', 'Sales': 19.46, 'Quantity': 7, 'Discount': 0.0, 'Profit': 5.0596}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef33'), 'Row ID': 23, 'Order ID': 'CA-2016-137330', 'Order Date': '12/9/2016', 'Ship Date': '12/13/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'KB-16585', 'Customer Name': 'Ken Black', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Fremont', 'State': 'Nebraska', 'Postal Code': 68025, 'Region': 'Central', 'Product ID': 'OFF-AP-10001492', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': "Acco Six-Outlet Power Strip, 4' Cord Length", 'Sales': 60.34, 'Quantity': 7, 'Discount': 0.0, 'Profit': 15.6884}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef34'), 'Row ID': 24, 'Order ID': 'US-2017-156909', 'Order Date': '7/16/2017', 'Ship Date': '7/18/2017', 'Ship Mode': 'Second Class', 'Customer ID': 'SF-20065', 'Customer Name': 'Sandra Flanagan', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19140, 'Region': 'East', 'Product ID': 'FUR-CH-10002774', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Global Deluxe Stacking Chair, Gray', 'Sales': 71.372, 'Quantity': 2, 'Discount': 0.3, 'Profit': -1.0196}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef35'), 'Row ID': 25, 'Order ID': 'CA-2015-106320', 'Order Date': '9/25/2015', 'Ship Date': '9/30/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'EB-13870', 'Customer Name': 'Emily Burns', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Orem', 'State': 'Utah', 'Postal Code': 84057, 'Region': 'West', 'Product ID': 'FUR-TA-10000577', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bretford CR4500 Series Slim Rectangular Table', 'Sales': 1044.63, 'Quantity': 3, 'Discount': 0.0, 'Profit': 240.2649}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef36'), 'Row ID': 26, 'Order ID': 'CA-2016-121755', 'Order Date': '1/16/2016', 'Ship Date': '1/20/2016', 'Ship Mode': 'Second Class', 'Customer ID': 'EH-13945', 'Customer Name': 'Eric Hoffmann', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90049, 'Region': 'West', 'Product ID': 'OFF-BI-10001634', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Wilson Jones Active Use Binders', 'Sales': 11.648, 'Quantity': 2, 'Discount': 0.2, 'Profit': 4.2224}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef37'), 'Row ID': 27, 'Order ID': 'CA-2016-121755', 'Order Date': '1/16/2016', 'Ship Date': '1/20/2016', 'Ship Mode': 'Second Class', 'Customer ID': 'EH-13945', 'Customer Name': 'Eric Hoffmann', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90049, 'Region': 'West', 'Product ID': 'TEC-AC-10003027', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Imation\xa08GB Mini TravelDrive USB 2.0\xa0Flash Drive', 'Sales': 90.57, 'Quantity': 3, 'Discount': 0.0, 'Profit': 11.7741}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef38'), 'Row ID': 28, 'Order ID': 'US-2015-150630', 'Order Date': '9/17/2015', 'Ship Date': '9/21/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19140, 'Region': 'East', 'Product ID': 'FUR-BO-10004834', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish', 'Sales': 3083.43, 'Quantity': 7, 'Discount': 0.5, 'Profit': -1665.0522}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef39'), 'Row ID': 29, 'Order ID': 'US-2015-150630', 'Order Date': '9/17/2015', 'Ship Date': '9/21/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19140, 'Region': 'East', 'Product ID': 'OFF-BI-10000474', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Avery Recycled Flexi-View Covers for Binding Systems', 'Sales': 9.618, 'Quantity': 2, 'Discount': 0.7, 'Profit': -7.0532}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef3a'), 'Row ID': 30, 'Order ID': 'US-2015-150630', 'Order Date': '9/17/2015', 'Ship Date': '9/21/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19140, 'Region': 'East', 'Product ID': 'FUR-FU-10004848', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Howard Miller 13-3/4" Diameter Brushed Chrome Round Wall Clock', 'Sales': 124.2, 'Quantity': 3, 'Discount': 0.2, 'Profit': 15.525}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef3b'), 'Row ID': 31, 'Order ID': 'US-2015-150630', 'Order Date': '9/17/2015', 'Ship Date': '9/21/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19140, 'Region': 'East', 'Product ID': 'OFF-EN-10001509', 'Category': 'Office Supplies', 'Sub-Category': 'Envelopes', 'Product Name': 'Poly String Tie Envelopes', 'Sales': 3.264, 'Quantity': 2, 'Discount': 0.2, 'Profit': 1.1016}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef3c'), 'Row ID': 32, 'Order ID': 'US-2015-150630', 'Order Date': '9/17/2015', 'Ship Date': '9/21/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19140, 'Region': 'East', 'Product ID': 'OFF-AR-10004042', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'BOSTON Model 1800 Electric Pencil Sharpeners, Putty/Woodgrain', 'Sales': 86.304, 'Quantity': 6, 'Discount': 0.2, 'Profit': 9.7092}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef3d'), 'Row ID': 33, 'Order ID': 'US-2015-150630', 'Order Date': '9/17/2015', 'Ship Date': '9/21/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19140, 'Region': 'East', 'Product ID': 'OFF-BI-10001525', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Acco Pressboard Covers with Storage Hooks, 14 7/8" x 11", Executive Red', 'Sales': 6.858, 'Quantity': 6, 'Discount': 0.7, 'Profit': -5.715}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef3e'), 'Row ID': 34, 'Order ID': 'US-2015-150630', 'Order Date': '9/17/2015', 'Ship Date': '9/21/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19140, 'Region': 'East', 'Product ID': 'OFF-AR-10001683', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Lumber Crayons', 'Sales': 15.76, 'Quantity': 2, 'Discount': 0.2, 'Profit': 3.546}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef3f'), 'Row ID': 35, 'Order ID': 'CA-2017-107727', 'Order Date': '10/19/2017', 'Ship Date': '10/23/2017', 'Ship Mode': 'Second Class', 'Customer ID': 'MA-17560', 'Customer Name': 'Matt Abelman', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77095, 'Region': 'Central', 'Product ID': 'OFF-PA-10000249', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Easy-staple paper', 'Sales': 29.472, 'Quantity': 3, 'Discount': 0.2, 'Profit': 9.9468}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef40'), 'Row ID': 36, 'Order ID': 'CA-2016-117590', 'Order Date': '12/8/2016', 'Ship Date': '12/10/2016', 'Ship Mode': 'First Class', 'Customer ID': 'GH-14485', 'Customer Name': 'Gene Hale', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Richardson', 'State': 'Texas', 'Postal Code': 75080, 'Region': 'Central', 'Product ID': 'TEC-PH-10004977', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'GE 30524EE4', 'Sales': 1097.544, 'Quantity': 7, 'Discount': 0.2, 'Profit': 123.4737}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef41'), 'Row ID': 37, 'Order ID': 'CA-2016-117590', 'Order Date': '12/8/2016', 'Ship Date': '12/10/2016', 'Ship Mode': 'First Class', 'Customer ID': 'GH-14485', 'Customer Name': 'Gene Hale', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Richardson', 'State': 'Texas', 'Postal Code': 75080, 'Region': 'Central', 'Product ID': 'FUR-FU-10003664', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': "Electrix Architect's Clamp-On Swing Arm Lamp, Black", 'Sales': 190.92, 'Quantity': 5, 'Discount': 0.6, 'Profit': -147.963}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef42'), 'Row ID': 38, 'Order ID': 'CA-2015-117415', 'Order Date': '12/27/2015', 'Ship Date': '12/31/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'SN-20710', 'Customer Name': 'Steve Nguyen', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77041, 'Region': 'Central', 'Product ID': 'OFF-EN-10002986', 'Category': 'Office Supplies', 'Sub-Category': 'Envelopes', 'Product Name': '#10-4 1/8" x 9 1/2" Premium Diagonal Seam Envelopes', 'Sales': 113.328, 'Quantity': 9, 'Discount': 0.2, 'Profit': 35.415}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef43'), 'Row ID': 39, 'Order ID': 'CA-2015-117415', 'Order Date': '12/27/2015', 'Ship Date': '12/31/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'SN-20710', 'Customer Name': 'Steve Nguyen', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77041, 'Region': 'Central', 'Product ID': 'FUR-BO-10002545', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Atlantic Metals Mobile 3-Shelf Bookcases, Custom Colors', 'Sales': 532.3992, 'Quantity': 3, 'Discount': 0.32, 'Profit': -46.9764}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef44'), 'Row ID': 40, 'Order ID': 'CA-2015-117415', 'Order Date': '12/27/2015', 'Ship Date': '12/31/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'SN-20710', 'Customer Name': 'Steve Nguyen', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77041, 'Region': 'Central', 'Product ID': 'FUR-CH-10004218', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': "Global Fabric Manager's Chair, Dark Gray", 'Sales': 212.058, 'Quantity': 3, 'Discount': 0.3, 'Profit': -15.147}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef45'), 'Row ID': 41, 'Order ID': 'CA-2015-117415', 'Order Date': '12/27/2015', 'Ship Date': '12/31/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'SN-20710', 'Customer Name': 'Steve Nguyen', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77041, 'Region': 'Central', 'Product ID': 'TEC-PH-10000486', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Plantronics HL10 Handset Lifter', 'Sales': 371.168, 'Quantity': 4, 'Discount': 0.2, 'Profit': 41.7564}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef46'), 'Row ID': 42, 'Order ID': 'CA-2017-120999', 'Order Date': '9/10/2017', 'Ship Date': '9/15/2017', 'Ship Mode': 'Standard Class', 'Customer ID': 'LC-16930', 'Customer Name': 'Linda Cazamias', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Naperville', 'State': 'Illinois', 'Postal Code': 60540, 'Region': 'Central', 'Product ID': 'TEC-PH-10004093', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Panasonic Kx-TS550', 'Sales': 147.168, 'Quantity': 4, 'Discount': 0.2, 'Profit': 16.5564}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef47'), 'Row ID': 43, 'Order ID': 'CA-2016-101343', 'Order Date': '7/17/2016', 'Ship Date': '7/22/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'RA-19885', 'Customer Name': 'Ruben Ausman', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90049, 'Region': 'West', 'Product ID': 'OFF-ST-10003479', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Eldon Base for stackable storage shelf, platinum', 'Sales': 77.88, 'Quantity': 2, 'Discount': 0.0, 'Profit': 3.894}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef48'), 'Row ID': 44, 'Order ID': 'CA-2017-139619', 'Order Date': '9/19/2017', 'Ship Date': '9/23/2017', 'Ship Mode': 'Standard Class', 'Customer ID': 'ES-14080', 'Customer Name': 'Erin Smith', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Melbourne', 'State': 'Florida', 'Postal Code': 32935, 'Region': 'South', 'Product ID': 'OFF-ST-10003282', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Advantus 10-Drawer Portable Organizer, Chrome Metal Frame, Smoke Drawers', 'Sales': 95.616, 'Quantity': 2, 'Discount': 0.2, 'Profit': 9.5616}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef49'), 'Row ID': 45, 'Order ID': 'CA-2016-118255', 'Order Date': '3/11/2016', 'Ship Date': '3/13/2016', 'Ship Mode': 'First Class', 'Customer ID': 'ON-18715', 'Customer Name': 'Odella Nelson', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Eagan', 'State': 'Minnesota', 'Postal Code': 55122, 'Region': 'Central', 'Product ID': 'TEC-AC-10000171', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Verbatim 25 GB 6x Blu-ray Single Layer Recordable Disc, 25/Pack', 'Sales': 45.98, 'Quantity': 2, 'Discount': 0.0, 'Profit': 19.7714}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef4a'), 'Row ID': 46, 'Order ID': 'CA-2016-118255', 'Order Date': '3/11/2016', 'Ship Date': '3/13/2016', 'Ship Mode': 'First Class', 'Customer ID': 'ON-18715', 'Customer Name': 'Odella Nelson', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Eagan', 'State': 'Minnesota', 'Postal Code': 55122, 'Region': 'Central', 'Product ID': 'OFF-BI-10003291', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Wilson Jones Leather-Like Binders with DublLock Round Rings', 'Sales': 17.46, 'Quantity': 2, 'Discount': 0.0, 'Profit': 8.2062}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef4b'), 'Row ID': 47, 'Order ID': 'CA-2014-146703', 'Order Date': '10/20/2014', 'Ship Date': '10/25/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'PO-18865', 'Customer Name': "Patrick O'Donnell", 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Westland', 'State': 'Michigan', 'Postal Code': 48185, 'Region': 'Central', 'Product ID': 'OFF-ST-10001713', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Gould Plastics 9-Pocket Panel Bin, 18-3/8w x 5-1/4d x 20-1/2h, Black', 'Sales': 211.96, 'Quantity': 4, 'Discount': 0.0, 'Profit': 8.4784}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef4c'), 'Row ID': 48, 'Order ID': 'CA-2016-169194', 'Order Date': '6/20/2016', 'Ship Date': '6/25/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'LH-16900', 'Customer Name': 'Lena Hernandez', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Dover', 'State': 'Delaware', 'Postal Code': 19901, 'Region': 'East', 'Product ID': 'TEC-AC-10002167', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Imation\xa08gb Micro Traveldrive Usb 2.0\xa0Flash Drive', 'Sales': 45.0, 'Quantity': 3, 'Discount': 0.0, 'Profit': 4.95}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef4d'), 'Row ID': 49, 'Order ID': 'CA-2016-169194', 'Order Date': '6/20/2016', 'Ship Date': '6/25/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'LH-16900', 'Customer Name': 'Lena Hernandez', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Dover', 'State': 'Delaware', 'Postal Code': 19901, 'Region': 'East', 'Product ID': 'TEC-PH-10003988', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'LF Elite 3D Dazzle Designer Hard Case Cover, Lf Stylus Pen and Wiper For Apple Iphone 5c Mini Lite', 'Sales': 21.8, 'Quantity': 2, 'Discount': 0.0, 'Profit': 6.104}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef4e'), 'Row ID': 50, 'Order ID': 'CA-2015-115742', 'Order Date': '4/18/2015', 'Ship Date': '4/22/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'DP-13000', 'Customer Name': 'Darren Powers', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'New Albany', 'State': 'Indiana', 'Postal Code': 47150, 'Region': 'Central', 'Product ID': 'OFF-BI-10004410', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'C-Line Peel & Stick Add-On Filing Pockets, 8-3/4 x 5-1/8, 10/Pack', 'Sales': 38.22, 'Quantity': 6, 'Discount': 0.0, 'Profit': 17.9634}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef4f'), 'Row ID': 51, 'Order ID': 'CA-2015-115742', 'Order Date': '4/18/2015', 'Ship Date': '4/22/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'DP-13000', 'Customer Name': 'Darren Powers', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'New Albany', 'State': 'Indiana', 'Postal Code': 47150, 'Region': 'Central', 'Product ID': 'OFF-LA-10002762', 'Category': 'Office Supplies', 'Sub-Category': 'Labels', 'Product Name': 'Avery 485', 'Sales': 75.18, 'Quantity': 6, 'Discount': 0.0, 'Profit': 35.3346}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef50'), 'Row ID': 52, 'Order ID': 'CA-2015-115742', 'Order Date': '4/18/2015', 'Ship Date': '4/22/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'DP-13000', 'Customer Name': 'Darren Powers', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'New Albany', 'State': 'Indiana', 'Postal Code': 47150, 'Region': 'Central', 'Product ID': 'FUR-FU-10001706', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Longer-Life Soft White Bulbs', 'Sales': 6.16, 'Quantity': 2, 'Discount': 0.0, 'Profit': 2.9568}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef51'), 'Row ID': 53, 'Order ID': 'CA-2015-115742', 'Order Date': '4/18/2015', 'Ship Date': '4/22/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'DP-13000', 'Customer Name': 'Darren Powers', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'New Albany', 'State': 'Indiana', 'Postal Code': 47150, 'Region': 'Central', 'Product ID': 'FUR-CH-10003061', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Global Leather Task Chair, Black', 'Sales': 89.99, 'Quantity': 1, 'Discount': 0.0, 'Profit': 17.0981}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef52'), 'Row ID': 54, 'Order ID': 'CA-2016-105816', 'Order Date': '12/11/2016', 'Ship Date': '12/17/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'JM-15265', 'Customer Name': 'Janet Molinari', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10024, 'Region': 'East', 'Product ID': 'OFF-FA-10000304', 'Category': 'Office Supplies', 'Sub-Category': 'Fasteners', 'Product Name': 'Advantus Push Pins', 'Sales': 15.26, 'Quantity': 7, 'Discount': 0.0, 'Profit': 6.2566}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef53'), 'Row ID': 55, 'Order ID': 'CA-2016-105816', 'Order Date': '12/11/2016', 'Ship Date': '12/17/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'JM-15265', 'Customer Name': 'Janet Molinari', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10024, 'Region': 'East', 'Product ID': 'TEC-PH-10002447', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'AT&T CL83451 4-Handset Telephone', 'Sales': 1029.95, 'Quantity': 5, 'Discount': 0.0, 'Profit': 298.6855}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef54'), 'Row ID': 56, 'Order ID': 'CA-2016-111682', 'Order Date': '6/17/2016', 'Ship Date': '6/18/2016', 'Ship Mode': 'First Class', 'Customer ID': 'TB-21055', 'Customer Name': 'Ted Butterfield', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Troy', 'State': 'New York', 'Postal Code': 12180, 'Region': 'East', 'Product ID': 'OFF-ST-10000604', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Home/Office Personal File Carts', 'Sales': 208.56, 'Quantity': 6, 'Discount': 0.0, 'Profit': 52.14}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef55'), 'Row ID': 57, 'Order ID': 'CA-2016-111682', 'Order Date': '6/17/2016', 'Ship Date': '6/18/2016', 'Ship Mode': 'First Class', 'Customer ID': 'TB-21055', 'Customer Name': 'Ted Butterfield', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Troy', 'State': 'New York', 'Postal Code': 12180, 'Region': 'East', 'Product ID': 'OFF-PA-10001569', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Xerox 232', 'Sales': 32.4, 'Quantity': 5, 'Discount': 0.0, 'Profit': 15.552}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef56'), 'Row ID': 58, 'Order ID': 'CA-2016-111682', 'Order Date': '6/17/2016', 'Ship Date': '6/18/2016', 'Ship Mode': 'First Class', 'Customer ID': 'TB-21055', 'Customer Name': 'Ted Butterfield', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Troy', 'State': 'New York', 'Postal Code': 12180, 'Region': 'East', 'Product ID': 'FUR-CH-10003968', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Novimex Turbo Task Chair', 'Sales': 319.41, 'Quantity': 5, 'Discount': 0.1, 'Profit': 7.098}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef57'), 'Row ID': 59, 'Order ID': 'CA-2016-111682', 'Order Date': '6/17/2016', 'Ship Date': '6/18/2016', 'Ship Mode': 'First Class', 'Customer ID': 'TB-21055', 'Customer Name': 'Ted Butterfield', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Troy', 'State': 'New York', 'Postal Code': 12180, 'Region': 'East', 'Product ID': 'OFF-PA-10000587', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Array Parchment Paper, Assorted Colors', 'Sales': 14.56, 'Quantity': 2, 'Discount': 0.0, 'Profit': 6.9888}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef58'), 'Row ID': 60, 'Order ID': 'CA-2016-111682', 'Order Date': '6/17/2016', 'Ship Date': '6/18/2016', 'Ship Mode': 'First Class', 'Customer ID': 'TB-21055', 'Customer Name': 'Ted Butterfield', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Troy', 'State': 'New York', 'Postal Code': 12180, 'Region': 'East', 'Product ID': 'TEC-AC-10002167', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Imation\xa08gb Micro Traveldrive Usb 2.0\xa0Flash Drive', 'Sales': 30.0, 'Quantity': 2, 'Discount': 0.0, 'Profit': 3.3}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef59'), 'Row ID': 61, 'Order ID': 'CA-2016-111682', 'Order Date': '6/17/2016', 'Ship Date': '6/18/2016', 'Ship Mode': 'First Class', 'Customer ID': 'TB-21055', 'Customer Name': 'Ted Butterfield', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Troy', 'State': 'New York', 'Postal Code': 12180, 'Region': 'East', 'Product ID': 'OFF-BI-10001460', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Plastic Binding Combs', 'Sales': 48.48, 'Quantity': 4, 'Discount': 0.2, 'Profit': 16.362}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef5a'), 'Row ID': 62, 'Order ID': 'CA-2016-111682', 'Order Date': '6/17/2016', 'Ship Date': '6/18/2016', 'Ship Mode': 'First Class', 'Customer ID': 'TB-21055', 'Customer Name': 'Ted Butterfield', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Troy', 'State': 'New York', 'Postal Code': 12180, 'Region': 'East', 'Product ID': 'OFF-AR-10001868', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Prang Dustless Chalk Sticks', 'Sales': 1.68, 'Quantity': 1, 'Discount': 0.0, 'Profit': 0.84}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef5b'), 'Row ID': 63, 'Order ID': 'CA-2015-135545', 'Order Date': '11/24/2015', 'Ship Date': '11/30/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'KM-16720', 'Customer Name': 'Kunst Miller', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90004, 'Region': 'West', 'Product ID': 'TEC-AC-10004633', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Verbatim 25 GB 6x Blu-ray Single Layer Recordable Disc, 3/Pack', 'Sales': 13.98, 'Quantity': 2, 'Discount': 0.0, 'Profit': 6.1512}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef5c'), 'Row ID': 64, 'Order ID': 'CA-2015-135545', 'Order Date': '11/24/2015', 'Ship Date': '11/30/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'KM-16720', 'Customer Name': 'Kunst Miller', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90004, 'Region': 'West', 'Product ID': 'OFF-BI-10001078', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Acco PRESSTEX Data Binder with Storage Hooks, Dark Blue, 14 7/8" X 11"', 'Sales': 25.824, 'Quantity': 6, 'Discount': 0.2, 'Profit': 9.3612}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef5d'), 'Row ID': 65, 'Order ID': 'CA-2015-135545', 'Order Date': '11/24/2015', 'Ship Date': '11/30/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'KM-16720', 'Customer Name': 'Kunst Miller', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90004, 'Region': 'West', 'Product ID': 'OFF-PA-10003892', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Xerox 1943', 'Sales': 146.73, 'Quantity': 3, 'Discount': 0.0, 'Profit': 68.9631}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef5e'), 'Row ID': 66, 'Order ID': 'CA-2015-135545', 'Order Date': '11/24/2015', 'Ship Date': '11/30/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'KM-16720', 'Customer Name': 'Kunst Miller', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90004, 'Region': 'West', 'Product ID': 'FUR-FU-10000397', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Luxo Economy Swing Arm Lamp', 'Sales': 79.76, 'Quantity': 4, 'Discount': 0.0, 'Profit': 22.3328}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef5f'), 'Row ID': 67, 'Order ID': 'US-2015-164175', 'Order Date': '4/30/2015', 'Ship Date': '5/5/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'PS-18970', 'Customer Name': 'Paul Stevenson', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Chicago', 'State': 'Illinois', 'Postal Code': 60610, 'Region': 'Central', 'Product ID': 'FUR-CH-10001146', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': "Global Value Mid-Back Manager's Chair, Gray", 'Sales': 213.115, 'Quantity': 5, 'Discount': 0.3, 'Profit': -15.2225}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef60'), 'Row ID': 68, 'Order ID': 'CA-2014-106376', 'Order Date': '12/5/2014', 'Ship Date': '12/10/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BS-11590', 'Customer Name': 'Brendan Sweed', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Gilbert', 'State': 'Arizona', 'Postal Code': 85234, 'Region': 'West', 'Product ID': 'OFF-AR-10002671', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Hunt BOSTON Model 1606 High-Volume Electric Pencil Sharpener, Beige', 'Sales': 1113.024, 'Quantity': 8, 'Discount': 0.2, 'Profit': 111.3024}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef61'), 'Row ID': 69, 'Order ID': 'CA-2014-106376', 'Order Date': '12/5/2014', 'Ship Date': '12/10/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BS-11590', 'Customer Name': 'Brendan Sweed', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Gilbert', 'State': 'Arizona', 'Postal Code': 85234, 'Region': 'West', 'Product ID': 'TEC-PH-10002726', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'netTALK DUO VoIP Telephone Service', 'Sales': 167.968, 'Quantity': 4, 'Discount': 0.2, 'Profit': 62.988}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef62'), 'Row ID': 70, 'Order ID': 'CA-2016-119823', 'Order Date': '6/4/2016', 'Ship Date': '6/6/2016', 'Ship Mode': 'First Class', 'Customer ID': 'KD-16270', 'Customer Name': 'Karen Daniels', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Springfield', 'State': 'Virginia', 'Postal Code': 22153, 'Region': 'South', 'Product ID': 'OFF-PA-10000482', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Snap-A-Way Black Print Carbonless Ruled Speed Letter, Triplicate', 'Sales': 75.88, 'Quantity': 2, 'Discount': 0.0, 'Profit': 35.6636}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef63'), 'Row ID': 71, 'Order ID': 'CA-2016-106075', 'Order Date': '9/18/2016', 'Ship Date': '9/23/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'HM-14980', 'Customer Name': 'Henry MacAllister', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10009, 'Region': 'East', 'Product ID': 'OFF-BI-10004654', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Avery Binding System Hidden Tab Executive Style Index Sets', 'Sales': 4.616, 'Quantity': 1, 'Discount': 0.2, 'Profit': 1.731}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef64'), 'Row ID': 72, 'Order ID': 'CA-2017-114440', 'Order Date': '9/14/2017', 'Ship Date': '9/17/2017', 'Ship Mode': 'Second Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Jackson', 'State': 'Michigan', 'Postal Code': 49201, 'Region': 'Central', 'Product ID': 'OFF-PA-10004675', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Telephone Message Books with Fax/Mobile Section, 5 1/2" x 3 3/16"', 'Sales': 19.05, 'Quantity': 3, 'Discount': 0.0, 'Profit': 8.763}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef65'), 'Row ID': 73, 'Order ID': 'US-2015-134026', 'Order Date': '4/26/2015', 'Ship Date': '5/2/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'JE-15745', 'Customer Name': 'Joel Eaton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Memphis', 'State': 'Tennessee', 'Postal Code': 38109, 'Region': 'South', 'Product ID': 'FUR-CH-10000513', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': "High-Back Leather Manager's Chair", 'Sales': 831.936, 'Quantity': 8, 'Discount': 0.2, 'Profit': -114.3912}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef66'), 'Row ID': 74, 'Order ID': 'US-2015-134026', 'Order Date': '4/26/2015', 'Ship Date': '5/2/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'JE-15745', 'Customer Name': 'Joel Eaton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Memphis', 'State': 'Tennessee', 'Postal Code': 38109, 'Region': 'South', 'Product ID': 'FUR-FU-10003708', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Tenex Traditional Chairmats for Medium Pile Carpet, Standard Lip, 36" x 48"', 'Sales': 97.04, 'Quantity': 2, 'Discount': 0.2, 'Profit': 1.213}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef67'), 'Row ID': 75, 'Order ID': 'US-2015-134026', 'Order Date': '4/26/2015', 'Ship Date': '5/2/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'JE-15745', 'Customer Name': 'Joel Eaton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Memphis', 'State': 'Tennessee', 'Postal Code': 38109, 'Region': 'South', 'Product ID': 'OFF-ST-10004123', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Safco Industrial Wire Shelving System', 'Sales': 72.784, 'Quantity': 1, 'Discount': 0.2, 'Profit': -18.196}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef68'), 'Row ID': 76, 'Order ID': 'US-2017-118038', 'Order Date': '12/9/2017', 'Ship Date': '12/11/2017', 'Ship Mode': 'First Class', 'Customer ID': 'KB-16600', 'Customer Name': 'Ken Brennan', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77041, 'Region': 'Central', 'Product ID': 'OFF-BI-10004182', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Economy Binders', 'Sales': 1.248, 'Quantity': 3, 'Discount': 0.8, 'Profit': -1.9344}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef69'), 'Row ID': 77, 'Order ID': 'US-2017-118038', 'Order Date': '12/9/2017', 'Ship Date': '12/11/2017', 'Ship Mode': 'First Class', 'Customer ID': 'KB-16600', 'Customer Name': 'Ken Brennan', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77041, 'Region': 'Central', 'Product ID': 'FUR-FU-10000260', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': '6" Cubicle Wall Clock, Black', 'Sales': 9.708, 'Quantity': 3, 'Discount': 0.6, 'Profit': -5.8248}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef6a'), 'Row ID': 78, 'Order ID': 'US-2017-118038', 'Order Date': '12/9/2017', 'Ship Date': '12/11/2017', 'Ship Mode': 'First Class', 'Customer ID': 'KB-16600', 'Customer Name': 'Ken Brennan', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77041, 'Region': 'Central', 'Product ID': 'OFF-ST-10000615', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'SimpliFile Personal File, Black Granite, 15w x 6-15/16d x 11-1/4h', 'Sales': 27.24, 'Quantity': 3, 'Discount': 0.2, 'Profit': 2.724}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef6b'), 'Row ID': 79, 'Order ID': 'US-2014-147606', 'Order Date': '11/26/2014', 'Ship Date': '12/1/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'JE-15745', 'Customer Name': 'Joel Eaton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77070, 'Region': 'Central', 'Product ID': 'FUR-FU-10003194', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Eldon Expressions Desk Accessory, Wood Pencil Holder, Oak', 'Sales': 19.3, 'Quantity': 5, 'Discount': 0.6, 'Profit': -14.475}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef6c'), 'Row ID': 80, 'Order ID': 'CA-2016-127208', 'Order Date': '6/12/2016', 'Ship Date': '6/15/2016', 'Ship Mode': 'First Class', 'Customer ID': 'SC-20770', 'Customer Name': 'Stewart Carmichael', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Decatur', 'State': 'Alabama', 'Postal Code': 35601, 'Region': 'South', 'Product ID': 'OFF-AP-10002118', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': '1.7 Cubic Foot Compact "Cube" Office Refrigerators', 'Sales': 208.16, 'Quantity': 1, 'Discount': 0.0, 'Profit': 56.2032}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef6d'), 'Row ID': 81, 'Order ID': 'CA-2016-127208', 'Order Date': '6/12/2016', 'Ship Date': '6/15/2016', 'Ship Mode': 'First Class', 'Customer ID': 'SC-20770', 'Customer Name': 'Stewart Carmichael', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Decatur', 'State': 'Alabama', 'Postal Code': 35601, 'Region': 'South', 'Product ID': 'OFF-BI-10002309', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Avery Heavy-Duty EZD  Binder With Locking Rings', 'Sales': 16.74, 'Quantity': 3, 'Discount': 0.0, 'Profit': 8.0352}
# ...
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0e9'), 'Row ID': 461, 'Order ID': 'CA-2015-109638', 'Order Date': '12/15/2015', 'Ship Date': '12/22/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'JH-15985', 'Customer Name': 'Joseph Holt', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal Code': 98115, 'Region': 'West', 'Product ID': 'TEC-AC-10004571', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Logitech G700s Rechargeable Gaming Mouse', 'Sales': 899.91, 'Quantity': 9, 'Discount': 0.0, 'Profit': 377.9622}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0ea'), 'Row ID': 462, 'Order ID': 'CA-2015-109638', 'Order Date': '12/15/2015', 'Ship Date': '12/22/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'JH-15985', 'Customer Name': 'Joseph Holt', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal Code': 98115, 'Region': 'West', 'Product ID': 'OFF-BI-10001098', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Acco D-Ring Binder w/DublLock', 'Sales': 51.312, 'Quantity': 3, 'Discount': 0.2, 'Profit': 18.6006}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0eb'), 'Row ID': 463, 'Order ID': 'CA-2016-109869', 'Order Date': '4/22/2016', 'Ship Date': '4/29/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'TN-21040', 'Customer Name': 'Tanja Norvell', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Phoenix', 'State': 'Arizona', 'Postal Code': 85023, 'Region': 'West', 'Product ID': 'FUR-FU-10000023', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Eldon Wave Desk Accessories', 'Sales': 23.56, 'Quantity': 5, 'Discount': 0.2, 'Profit': 7.068}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0ec'), 'Row ID': 464, 'Order ID': 'CA-2016-109869', 'Order Date': '4/22/2016', 'Ship Date': '4/29/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'TN-21040', 'Customer Name': 'Tanja Norvell', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Phoenix', 'State': 'Arizona', 'Postal Code': 85023, 'Region': 'West', 'Product ID': 'FUR-TA-10001889', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bush Advantage Collection Racetrack Conference Table', 'Sales': 1272.63, 'Quantity': 6, 'Discount': 0.5, 'Profit': -814.4832}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0ed'), 'Row ID': 465, 'Order ID': 'CA-2016-109869', 'Order Date': '4/22/2016', 'Ship Date': '4/29/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'TN-21040', 'Customer Name': 'Tanja Norvell', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Phoenix', 'State': 'Arizona', 'Postal Code': 85023, 'Region': 'West', 'Product ID': 'OFF-BI-10000315', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Poly Designer Cover & Back', 'Sales': 28.485, 'Quantity': 5, 'Discount': 0.7, 'Profit': -20.889}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0ee'), 'Row ID': 466, 'Order ID': 'CA-2016-109869', 'Order Date': '4/22/2016', 'Ship Date': '4/29/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'TN-21040', 'Customer Name': 'Tanja Norvell', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Phoenix', 'State': 'Arizona', 'Postal Code': 85023, 'Region': 'West', 'Product ID': 'OFF-SU-10003505', 'Category': 'Office Supplies', 'Sub-Category': 'Supplies', 'Product Name': 'Premier Electric Letter Opener', 'Sales': 185.376, 'Quantity': 2, 'Discount': 0.2, 'Profit': -34.758}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0ef'), 'Row ID': 467, 'Order ID': 'CA-2016-109869', 'Order Date': '4/22/2016', 'Ship Date': '4/29/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'TN-21040', 'Customer Name': 'Tanja Norvell', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Phoenix', 'State': 'Arizona', 'Postal Code': 85023, 'Region': 'West', 'Product ID': 'OFF-AP-10002578', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': 'Fellowes Premier Superior Surge Suppressor, 10-Outlet, With Phone and Remote', 'Sales': 78.272, 'Quantity': 2, 'Discount': 0.2, 'Profit': 5.8704}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0f0'), 'Row ID': 468, 'Order ID': 'US-2015-101399', 'Order Date': '1/17/2015', 'Ship Date': '1/24/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'JS-15940', 'Customer Name': 'Joni Sundaresam', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Park Ridge', 'State': 'Illinois', 'Postal Code': 60068, 'Region': 'Central', 'Product ID': 'FUR-FU-10002918', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Eldon ClusterMat Chair Mat with Cordless Antistatic Protection', 'Sales': 254.744, 'Quantity': 7, 'Discount': 0.6, 'Profit': -312.0614}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0f1'), 'Row ID': 469, 'Order ID': 'CA-2017-154907', 'Order Date': '3/31/2017', 'Ship Date': '4/4/2017', 'Ship Mode': 'Standard Class', 'Customer ID': 'DS-13180', 'Customer Name': 'David Smith', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Amarillo', 'State': 'Texas', 'Postal Code': 79109, 'Region': 'Central', 'Product ID': 'FUR-BO-10002824', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Bush Mission Pointe Library', 'Sales': 205.3328, 'Quantity': 2, 'Discount': 0.32, 'Profit': -36.2352}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0f2'), 'Row ID': 470, 'Order ID': 'US-2016-100419', 'Order Date': '12/16/2016', 'Ship Date': '12/20/2016', 'Ship Mode': 'Second Class', 'Customer ID': 'CC-12670', 'Customer Name': 'Craig Carreira', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Chicago', 'State': 'Illinois', 'Postal Code': 60610, 'Region': 'Central', 'Product ID': 'OFF-BI-10002194', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Cardinal Hold-It CD Pocket', 'Sales': 4.788, 'Quantity': 3, 'Discount': 0.8, 'Profit': -7.9002}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0f3'), 'Row ID': 471, 'Order ID': 'CA-2015-154144', 'Order Date': '12/20/2015', 'Ship Date': '12/24/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'MH-17785', 'Customer Name': 'Maya Herman', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Lindenhurst', 'State': 'New York', 'Postal Code': 11757, 'Region': 'East', 'Product ID': 'OFF-PA-10004071', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Eaton Premium Continuous-Feed Paper, 25% Cotton, Letter Size, White, 1000 Shts/Box', 'Sales': 55.48, 'Quantity': 1, 'Discount': 0.0, 'Profit': 26.6304}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0f4'), 'Row ID': 472, 'Order ID': 'CA-2014-144666', 'Order Date': '11/9/2014', 'Ship Date': '11/11/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'JP-15520', 'Customer Name': 'Jeremy Pistek', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94110, 'Region': 'West', 'Product ID': 'OFF-ST-10002743', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'SAFCO Boltless Steel Shelving', 'Sales': 340.92, 'Quantity': 3, 'Discount': 0.0, 'Profit': 3.4092}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0f5'), 'Row ID': 473, 'Order ID': 'CA-2014-144666', 'Order Date': '11/9/2014', 'Ship Date': '11/11/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'JP-15520', 'Customer Name': 'Jeremy Pistek', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94110, 'Region': 'West', 'Product ID': 'FUR-BO-10001601', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Sauder Mission Library with Doors, Fruitwood Finish', 'Sales': 222.666, 'Quantity': 2, 'Discount': 0.15, 'Profit': 10.4784}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0f6'), 'Row ID': 474, 'Order ID': 'CA-2014-144666', 'Order Date': '11/9/2014', 'Ship Date': '11/11/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'JP-15520', 'Customer Name': 'Jeremy Pistek', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94110, 'Region': 'West', 'Product ID': 'TEC-PH-10002680', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Samsung Galaxy Note 3', 'Sales': 703.968, 'Quantity': 4, 'Discount': 0.2, 'Profit': 87.996}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0f7'), 'Row ID': 475, 'Order ID': 'CA-2014-144666', 'Order Date': '11/9/2014', 'Ship Date': '11/11/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'JP-15520', 'Customer Name': 'Jeremy Pistek', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94110, 'Region': 'West', 'Product ID': 'OFF-ST-10001321', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Decoflex Hanging Personal Folder File, Blue', 'Sales': 92.52, 'Quantity': 6, 'Discount': 0.0, 'Profit': 24.9804}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0f8'), 'Row ID': 476, 'Order ID': 'CA-2014-144666', 'Order Date': '11/9/2014', 'Ship Date': '11/11/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'JP-15520', 'Customer Name': 'Jeremy Pistek', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94110, 'Region': 'West', 'Product ID': 'OFF-PA-10001509', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Recycled Desk Saver Line "While You Were Out" Book, 5 1/2" X 4"', 'Sales': 62.65, 'Quantity': 7, 'Discount': 0.0, 'Profit': 28.819}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0f9'), 'Row ID': 477, 'Order ID': 'CA-2014-144666', 'Order Date': '11/9/2014', 'Ship Date': '11/11/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'JP-15520', 'Customer Name': 'Jeremy Pistek', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94110, 'Region': 'West', 'Product ID': 'OFF-PA-10003465', 'Category': 'Office Supplies', 'Sub-Category': 'Paper', 'Product Name': 'Xerox 1912', 'Sales': 94.85, 'Quantity': 5, 'Discount': 0.0, 'Profit': 45.528}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0fa'), 'Row ID': 478, 'Order ID': 'CA-2016-103891', 'Order Date': '7/12/2016', 'Ship Date': '7/19/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'KH-16690', 'Customer Name': 'Kristen Hastings', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90008, 'Region': 'West', 'Product ID': 'TEC-PH-10000149', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Cisco SPA525G2 IP Phone - Wireless', 'Sales': 95.76, 'Quantity': 6, 'Discount': 0.2, 'Profit': 7.182}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0fb'), 'Row ID': 479, 'Order ID': 'CA-2016-152632', 'Order Date': '10/27/2016', 'Ship Date': '11/2/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'JE-15475', 'Customer Name': 'Jeremy Ellison', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Troy', 'State': 'New York', 'Postal Code': 12180, 'Region': 'East', 'Product ID': 'FUR-FU-10002671', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Electrix 20W Halogen Replacement Bulb for Zoom-In Desk Lamp', 'Sales': 40.2, 'Quantity': 3, 'Discount': 0.0, 'Profit': 19.296}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0fc'), 'Row ID': 480, 'Order ID': 'CA-2016-100790', 'Order Date': '6/26/2016', 'Ship Date': '7/2/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'JG-15805', 'Customer Name': 'John Grady', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10024, 'Region': 'East', 'Product ID': 'OFF-AR-10003045', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Prang Colored Pencils', 'Sales': 14.7, 'Quantity': 5, 'Discount': 0.0, 'Profit': 6.615}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0fd'), 'Row ID': 481, 'Order ID': 'CA-2016-100790', 'Order Date': '6/26/2016', 'Ship Date': '7/2/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'JG-15805', 'Customer Name': 'John Grady', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10024, 'Region': 'East', 'Product ID': 'OFF-ST-10000689', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Fellowes Strictly Business Drawer File, Letter/Legal Size', 'Sales': 704.25, 'Quantity': 5, 'Discount': 0.0, 'Profit': 84.51}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0fe'), 'Row ID': 482, 'Order ID': 'CA-2014-134677', 'Order Date': '10/6/2014', 'Ship Date': '10/10/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'XP-21865', 'Customer Name': 'Xylona Preis', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Diego', 'State': 'California', 'Postal Code': 92024, 'Region': 'West', 'Product ID': 'TEC-AC-10001445', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Imation\xa0USB 2.0 Swivel\xa0Flash Drive\xa0USB\xa0flash drive\xa0- 4 GB - Pink', 'Sales': 9.09, 'Quantity': 3, 'Discount': 0.0, 'Profit': 1.9089}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0ff'), 'Row ID': 483, 'Order ID': 'CA-2014-127691', 'Order Date': '7/22/2014', 'Ship Date': '7/27/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'EM-14065', 'Customer Name': 'Erin Mull', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10024, 'Region': 'East', 'Product ID': 'OFF-AR-10002053', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Premium Writing Pencils, Soft, #2 by Central Association for the Blind', 'Sales': 5.96, 'Quantity': 2, 'Discount': 0.0, 'Profit': 1.6688}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f100'), 'Row ID': 484, 'Order ID': 'CA-2014-127691', 'Order Date': '7/22/2014', 'Ship Date': '7/27/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'EM-14065', 'Customer Name': 'Erin Mull', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10024, 'Region': 'East', 'Product ID': 'TEC-AC-10002567', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Logitech G602 Wireless Gaming Mouse', 'Sales': 159.98, 'Quantity': 2, 'Discount': 0.0, 'Profit': 57.5928}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f101'), 'Row ID': 485, 'Order ID': 'CA-2017-140963', 'Order Date': '6/10/2017', 'Ship Date': '6/13/2017', 'Ship Mode': 'First Class', 'Customer ID': 'MT-18070', 'Customer Name': 'Michelle Tran', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90045, 'Region': 'West', 'Product ID': 'OFF-LA-10003923', 'Category': 'Office Supplies', 'Sub-Category': 'Labels', 'Product Name': 'Alphabetical Labels for Top Tab Filing', 'Sales': 29.6, 'Quantity': 2, 'Discount': 0.0, 'Profit': 14.8}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f102'), 'Row ID': 486, 'Order ID': 'CA-2017-140963', 'Order Date': '6/10/2017', 'Ship Date': '6/13/2017', 'Ship Mode': 'First Class', 'Customer ID': 'MT-18070', 'Customer Name': 'Michelle Tran', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90045, 'Region': 'West', 'Product ID': 'FUR-BO-10001337', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': "O'Sullivan Living Dimensions 2-Shelf Bookcases", 'Sales': 514.165, 'Quantity': 5, 'Discount': 0.15, 'Profit': -30.245}
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## 3) Count and display the total number of documents in the Orders collection

# %%
total_orders = orders_collection.count_documents({})
print(f"Total number of orders in the collection: {total_orders}")
# Out:
# Total number of orders in the collection: 19988

# %% [markdown]
#  ## 4) Query to fetch all orders from the "West" region

# %%
west_orders = orders_collection.find({"Region": "West"}).limit(10)

print("\nOrders from the West region (first 10):")
for order in west_orders:
    print(order)
# Out:
# Orders from the West region (first 10):
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef1f'), 'Row ID': 3, 'Order ID': 'CA-2016-138688', 'Order Date': '6/12/2016', 'Ship Date': '6/16/2016', 'Ship Mode': 'Second Class', 'Customer ID': 'DV-13045', 'Customer Name': 'Darrin Van Huff', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90036, 'Region': 'West', 'Product ID': 'OFF-LA-10000240', 'Category': 'Office Supplies', 'Sub-Category': 'Labels', 'Product Name': 'Self-Adhesive Address Labels for Typewriters by Universal', 'Sales': 14.62, 'Quantity': 2, 'Discount': 0.0, 'Profit': 6.8714}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef22'), 'Row ID': 6, 'Order ID': 'CA-2014-115812', 'Order Date': '6/9/2014', 'Ship Date': '6/14/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'FUR-FU-10001487', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Eldon Expressions Wood and Plastic Desk Accessories, Cherry Wood', 'Sales': 48.86, 'Quantity': 7, 'Discount': 0.0, 'Profit': 14.1694}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef23'), 'Row ID': 7, 'Order ID': 'CA-2014-115812', 'Order Date': '6/9/2014', 'Ship Date': '6/14/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'OFF-AR-10002833', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Newell 322', 'Sales': 7.28, 'Quantity': 4, 'Discount': 0.0, 'Profit': 1.9656}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef24'), 'Row ID': 8, 'Order ID': 'CA-2014-115812', 'Order Date': '6/9/2014', 'Ship Date': '6/14/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'TEC-PH-10002275', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Mitel 5320 IP Phone VoIP phone', 'Sales': 907.152, 'Quantity': 6, 'Discount': 0.2, 'Profit': 90.7152}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef25'), 'Row ID': 9, 'Order ID': 'CA-2014-115812', 'Order Date': '6/9/2014', 'Ship Date': '6/14/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'OFF-BI-10003910', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'DXL Angle-View Binders with Locking Rings by Samsill', 'Sales': 18.504, 'Quantity': 3, 'Discount': 0.2, 'Profit': 5.7825}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef26'), 'Row ID': 10, 'Order ID': 'CA-2014-115812', 'Order Date': '6/9/2014', 'Ship Date': '6/14/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'OFF-AP-10002892', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': 'Belkin F5C206VTEL 6 Outlet Surge', 'Sales': 114.9, 'Quantity': 5, 'Discount': 0.0, 'Profit': 34.47}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef27'), 'Row ID': 11, 'Order ID': 'CA-2014-115812', 'Order Date': '6/9/2014', 'Ship Date': '6/14/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'FUR-TA-10001539', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Chromcraft Rectangular Conference Tables', 'Sales': 1706.184, 'Quantity': 9, 'Discount': 0.2, 'Profit': 85.3092}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef28'), 'Row ID': 12, 'Order ID': 'CA-2014-115812', 'Order Date': '6/9/2014', 'Ship Date': '6/14/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'TEC-PH-10002033', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Konftel 250 Conference\xa0phone\xa0- Charcoal black', 'Sales': 911.424, 'Quantity': 4, 'Discount': 0.2, 'Profit': 68.3568}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef2a'), 'Row ID': 14, 'Order ID': 'CA-2016-161389', 'Order Date': '12/5/2016', 'Ship Date': '12/10/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'IM-15070', 'Customer Name': 'Irene Maddox', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal Code': 98103, 'Region': 'West', 'Product ID': 'OFF-BI-10003656', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Fellowes PB200 Plastic Comb Binding Machine', 'Sales': 407.976, 'Quantity': 3, 'Discount': 0.2, 'Profit': 132.5922}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef2e'), 'Row ID': 18, 'Order ID': 'CA-2014-167164', 'Order Date': '5/13/2014', 'Ship Date': '5/15/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'AG-10270', 'Customer Name': 'Alejandro Grove', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'West Jordan', 'State': 'Utah', 'Postal Code': 84084, 'Region': 'West', 'Product ID': 'OFF-ST-10000107', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Fellowes Super Stor/Drawer', 'Sales': 55.5, 'Quantity': 2, 'Discount': 0.0, 'Profit': 9.99}

# %% [markdown]
# ## 5) Query to find orders where Sales is greater than 500

# %%
high_sales_orders = orders_collection.find({"Sales": {"$gt": 500}})

print("\nOrders where Sales is greater than 500:")
for order in high_sales_orders:
    print(order)
# Out:
# Orders where Sales is greater than 500:
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef1e'), 'Row ID': 2, 'Order ID': 'CA-2016-152156', 'Order Date': '11/8/2016', 'Ship Date': '11/11/2016', 'Ship Mode': 'Second Class', 'Customer ID': 'CG-12520', 'Customer Name': 'Claire Gute', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Henderson', 'State': 'Kentucky', 'Postal Code': 42420, 'Region': 'South', 'Product ID': 'FUR-CH-10000454', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back', 'Sales': 731.94, 'Quantity': 3, 'Discount': 0.0, 'Profit': 219.582}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef20'), 'Row ID': 4, 'Order ID': 'US-2015-108966', 'Order Date': '10/11/2015', 'Ship Date': '10/18/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'SO-20335', 'Customer Name': "Sean O'Donnell", 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Fort Lauderdale', 'State': 'Florida', 'Postal Code': 33311, 'Region': 'South', 'Product ID': 'FUR-TA-10000577', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bretford CR4500 Series Slim Rectangular Table', 'Sales': 957.5775, 'Quantity': 5, 'Discount': 0.45, 'Profit': -383.031}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef24'), 'Row ID': 8, 'Order ID': 'CA-2014-115812', 'Order Date': '6/9/2014', 'Ship Date': '6/14/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'TEC-PH-10002275', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Mitel 5320 IP Phone VoIP phone', 'Sales': 907.152, 'Quantity': 6, 'Discount': 0.2, 'Profit': 90.7152}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef27'), 'Row ID': 11, 'Order ID': 'CA-2014-115812', 'Order Date': '6/9/2014', 'Ship Date': '6/14/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'FUR-TA-10001539', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Chromcraft Rectangular Conference Tables', 'Sales': 1706.184, 'Quantity': 9, 'Discount': 0.2, 'Profit': 85.3092}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef28'), 'Row ID': 12, 'Order ID': 'CA-2014-115812', 'Order Date': '6/9/2014', 'Ship Date': '6/14/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90032, 'Region': 'West', 'Product ID': 'TEC-PH-10002033', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Konftel 250 Conference\xa0phone\xa0- Charcoal black', 'Sales': 911.424, 'Quantity': 4, 'Discount': 0.2, 'Profit': 68.3568}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef2d'), 'Row ID': 17, 'Order ID': 'CA-2014-105893', 'Order Date': '11/11/2014', 'Ship Date': '11/18/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'PK-19075', 'Customer Name': 'Pete Kriz', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Madison', 'State': 'Wisconsin', 'Postal Code': 53711, 'Region': 'Central', 'Product ID': 'OFF-ST-10004186', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Stur-D-Stor Shelving, Vertical 5-Shelf: 72"H x 36"W x 18 1/2"D', 'Sales': 665.88, 'Quantity': 6, 'Discount': 0.0, 'Profit': 13.3176}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef35'), 'Row ID': 25, 'Order ID': 'CA-2015-106320', 'Order Date': '9/25/2015', 'Ship Date': '9/30/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'EB-13870', 'Customer Name': 'Emily Burns', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Orem', 'State': 'Utah', 'Postal Code': 84057, 'Region': 'West', 'Product ID': 'FUR-TA-10000577', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bretford CR4500 Series Slim Rectangular Table', 'Sales': 1044.63, 'Quantity': 3, 'Discount': 0.0, 'Profit': 240.2649}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef38'), 'Row ID': 28, 'Order ID': 'US-2015-150630', 'Order Date': '9/17/2015', 'Ship Date': '9/21/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'TB-21520', 'Customer Name': 'Tracy Blumstein', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19140, 'Region': 'East', 'Product ID': 'FUR-BO-10004834', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish', 'Sales': 3083.43, 'Quantity': 7, 'Discount': 0.5, 'Profit': -1665.0522}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef40'), 'Row ID': 36, 'Order ID': 'CA-2016-117590', 'Order Date': '12/8/2016', 'Ship Date': '12/10/2016', 'Ship Mode': 'First Class', 'Customer ID': 'GH-14485', 'Customer Name': 'Gene Hale', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Richardson', 'State': 'Texas', 'Postal Code': 75080, 'Region': 'Central', 'Product ID': 'TEC-PH-10004977', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'GE 30524EE4', 'Sales': 1097.544, 'Quantity': 7, 'Discount': 0.2, 'Profit': 123.4737}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef43'), 'Row ID': 39, 'Order ID': 'CA-2015-117415', 'Order Date': '12/27/2015', 'Ship Date': '12/31/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'SN-20710', 'Customer Name': 'Steve Nguyen', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77041, 'Region': 'Central', 'Product ID': 'FUR-BO-10002545', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Atlantic Metals Mobile 3-Shelf Bookcases, Custom Colors', 'Sales': 532.3992, 'Quantity': 3, 'Discount': 0.32, 'Profit': -46.9764}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef53'), 'Row ID': 55, 'Order ID': 'CA-2016-105816', 'Order Date': '12/11/2016', 'Ship Date': '12/17/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'JM-15265', 'Customer Name': 'Janet Molinari', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10024, 'Region': 'East', 'Product ID': 'TEC-PH-10002447', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'AT&T CL83451 4-Handset Telephone', 'Sales': 1029.95, 'Quantity': 5, 'Discount': 0.0, 'Profit': 298.6855}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef60'), 'Row ID': 68, 'Order ID': 'CA-2014-106376', 'Order Date': '12/5/2014', 'Ship Date': '12/10/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BS-11590', 'Customer Name': 'Brendan Sweed', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Gilbert', 'State': 'Arizona', 'Postal Code': 85234, 'Region': 'West', 'Product ID': 'OFF-AR-10002671', 'Category': 'Office Supplies', 'Sub-Category': 'Art', 'Product Name': 'Hunt BOSTON Model 1606 High-Volume Electric Pencil Sharpener, Beige', 'Sales': 1113.024, 'Quantity': 8, 'Discount': 0.2, 'Profit': 111.3024}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef65'), 'Row ID': 73, 'Order ID': 'US-2015-134026', 'Order Date': '4/26/2015', 'Ship Date': '5/2/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'JE-15745', 'Customer Name': 'Joel Eaton', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Memphis', 'State': 'Tennessee', 'Postal Code': 38109, 'Region': 'South', 'Product ID': 'FUR-CH-10000513', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': "High-Back Leather Manager's Chair", 'Sales': 831.936, 'Quantity': 8, 'Discount': 0.2, 'Profit': -114.3912}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef92'), 'Row ID': 118, 'Order ID': 'CA-2015-110457', 'Order Date': '3/2/2015', 'Ship Date': '3/6/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'DK-13090', 'Customer Name': 'Dave Kipp', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal Code': 98103, 'Region': 'West', 'Product ID': 'FUR-TA-10001768', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Hon Racetrack Conference Tables', 'Sales': 787.53, 'Quantity': 3, 'Discount': 0.0, 'Profit': 165.3813}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef99'), 'Row ID': 125, 'Order ID': 'US-2014-152030', 'Order Date': '12/26/2014', 'Ship Date': '12/28/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'AD-10180', 'Customer Name': 'Alan Dominguez', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77041, 'Region': 'Central', 'Product ID': 'FUR-CH-10004063', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': "Global Deluxe High-Back Manager's Chair", 'Sales': 600.558, 'Quantity': 3, 'Discount': 0.3, 'Profit': -8.5794}
# {'_id': ObjectId('67abb13f3bb89c39c0c8ef9a'), 'Row ID': 126, 'Order ID': 'US-2014-134614', 'Order Date': '9/20/2014', 'Ship Date': '9/25/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'PF-19165', 'Customer Name': 'Philip Fox', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Bloomington', 'State': 'Illinois', 'Postal Code': 61701, 'Region': 'Central', 'Product ID': 'FUR-TA-10004534', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bevis 44 x 96 Conference Tables', 'Sales': 617.7, 'Quantity': 6, 'Discount': 0.5, 'Profit': -407.682}
# {'_id': ObjectId('67abb13f3bb89c39c0c8efad'), 'Row ID': 145, 'Order ID': 'CA-2017-155376', 'Order Date': '12/22/2017', 'Ship Date': '12/27/2017', 'Ship Mode': 'Standard Class', 'Customer ID': 'SG-20080', 'Customer Name': 'Sandra Glassco', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Independence', 'State': 'Missouri', 'Postal Code': 64055, 'Region': 'Central', 'Product ID': 'OFF-AP-10001058', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': 'Sanyo 2.5 Cubic Foot Mid-Size Office Refrigerators', 'Sales': 839.43, 'Quantity': 3, 'Discount': 0.0, 'Profit': 218.2518}
# {'_id': ObjectId('67abb13f3bb89c39c0c8efae'), 'Row ID': 146, 'Order ID': 'CA-2015-110744', 'Order Date': '9/7/2015', 'Ship Date': '9/12/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'HA-14920', 'Customer Name': 'Helen Andreada', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Pasadena', 'State': 'California', 'Postal Code': 91104, 'Region': 'West', 'Product ID': 'OFF-ST-10003656', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Safco Industrial Wire Shelving', 'Sales': 671.93, 'Quantity': 7, 'Discount': 0.0, 'Profit': 20.1579}
# {'_id': ObjectId('67abb13f3bb89c39c0c8efb2'), 'Row ID': 150, 'Order ID': 'CA-2016-114489', 'Order Date': '12/5/2016', 'Ship Date': '12/9/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'JE-16165', 'Customer Name': 'Justin Ellison', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Franklin', 'State': 'Wisconsin', 'Postal Code': 53132, 'Region': 'Central', 'Product ID': 'FUR-CH-10000454', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back', 'Sales': 1951.84, 'Quantity': 8, 'Discount': 0.0, 'Profit': 585.552}
# {'_id': ObjectId('67abb13f3bb89c39c0c8efbc'), 'Row ID': 160, 'Order ID': 'CA-2016-114104', 'Order Date': '11/20/2016', 'Ship Date': '11/24/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'NP-18670', 'Customer Name': 'Nora Paige', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Edmond', 'State': 'Oklahoma', 'Postal Code': 73034, 'Region': 'Central', 'Product ID': 'TEC-PH-10004536', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Avaya 5420 Digital phone', 'Sales': 944.93, 'Quantity': 7, 'Discount': 0.0, 'Profit': 236.2325}
# {'_id': ObjectId('67abb13f3bb89c39c0c8efc2'), 'Row ID': 166, 'Order ID': 'CA-2014-139892', 'Order Date': '9/8/2014', 'Ship Date': '9/12/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BM-11140', 'Customer Name': 'Becky Martin', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Antonio', 'State': 'Texas', 'Postal Code': 78207, 'Region': 'Central', 'Product ID': 'TEC-MA-10000822', 'Category': 'Technology', 'Sub-Category': 'Machines', 'Product Name': 'Lexmark MX611dhe Monochrome Laser Printer', 'Sales': 8159.952, 'Quantity': 8, 'Discount': 0.4, 'Profit': -1359.992}
# {'_id': ObjectId('67abb13f3bb89c39c0c8efc4'), 'Row ID': 168, 'Order ID': 'CA-2014-139892', 'Order Date': '9/8/2014', 'Ship Date': '9/12/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BM-11140', 'Customer Name': 'Becky Martin', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Antonio', 'State': 'Texas', 'Postal Code': 78207, 'Region': 'Central', 'Product ID': 'FUR-CH-10004287', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'SAFCO Arco Folding Chair', 'Sales': 1740.06, 'Quantity': 9, 'Discount': 0.3, 'Profit': -24.858}
# {'_id': ObjectId('67abb13f3bb89c39c0c8efd3'), 'Row ID': 183, 'Order ID': 'CA-2014-158274', 'Order Date': '11/19/2014', 'Ship Date': '11/24/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'RM-19675', 'Customer Name': 'Robert Marley', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Monroe', 'State': 'Louisiana', 'Postal Code': 71203, 'Region': 'South', 'Product ID': 'TEC-PH-10003273', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'AT&T TR1909W', 'Sales': 503.96, 'Quantity': 4, 'Discount': 0.0, 'Profit': 131.0296}
# {'_id': ObjectId('67abb13f3bb89c39c0c8efda'), 'Row ID': 190, 'Order ID': 'CA-2015-102281', 'Order Date': '10/12/2015', 'Ship Date': '10/14/2015', 'Ship Mode': 'First Class', 'Customer ID': 'MP-17470', 'Customer Name': 'Mark Packer', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10035, 'Region': 'East', 'Product ID': 'FUR-BO-10002613', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Atlantic Metals Mobile 4-Shelf Bookcases, Custom Colors', 'Sales': 899.136, 'Quantity': 4, 'Discount': 0.2, 'Profit': 112.392}
# {'_id': ObjectId('67abb13f3bb89c39c0c8efdd'), 'Row ID': 193, 'Order ID': 'CA-2015-102281', 'Order Date': '10/12/2015', 'Ship Date': '10/14/2015', 'Ship Mode': 'First Class', 'Customer ID': 'MP-17470', 'Customer Name': 'Mark Packer', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10035, 'Region': 'East', 'Product ID': 'FUR-BO-10002545', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Atlantic Metals Mobile 3-Shelf Bookcases, Custom Colors', 'Sales': 626.352, 'Quantity': 3, 'Discount': 0.2, 'Profit': 46.9764}
# {'_id': ObjectId('67abb13f3bb89c39c0c8eff4'), 'Row ID': 216, 'Order ID': 'CA-2015-146262', 'Order Date': '1/2/2015', 'Ship Date': '1/9/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'VW-21775', 'Customer Name': 'Victoria Wilson', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Medina', 'State': 'Ohio', 'Postal Code': 44256, 'Region': 'East', 'Product ID': 'TEC-MA-10000864', 'Category': 'Technology', 'Sub-Category': 'Machines', 'Product Name': 'Cisco 9971 IP Video Phone Charcoal', 'Sales': 1188.0, 'Quantity': 9, 'Discount': 0.7, 'Profit': -950.4}
# {'_id': ObjectId('67abb13f3bb89c39c0c8efff'), 'Row ID': 227, 'Order ID': 'CA-2015-163055', 'Order Date': '8/9/2015', 'Ship Date': '8/16/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'DS-13180', 'Customer Name': 'David Smith', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Detroit', 'State': 'Michigan', 'Postal Code': 48227, 'Region': 'Central', 'Product ID': 'FUR-TA-10003748', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bevis 36 x 72 Conference Tables', 'Sales': 622.45, 'Quantity': 5, 'Discount': 0.0, 'Profit': 136.939}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f005'), 'Row ID': 233, 'Order ID': 'US-2017-100930', 'Order Date': '4/7/2017', 'Ship Date': '4/12/2017', 'Ship Mode': 'Standard Class', 'Customer ID': 'CS-12400', 'Customer Name': 'Christopher Schild', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Tampa', 'State': 'Florida', 'Postal Code': 33614, 'Region': 'South', 'Product ID': 'FUR-TA-10003473', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bretford Rectangular Conference Table Tops', 'Sales': 620.6145, 'Quantity': 3, 'Discount': 0.45, 'Profit': -248.2458}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f008'), 'Row ID': 236, 'Order ID': 'US-2017-100930', 'Order Date': '4/7/2017', 'Ship Date': '4/12/2017', 'Ship Mode': 'Standard Class', 'Customer ID': 'CS-12400', 'Customer Name': 'Christopher Schild', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Tampa', 'State': 'Florida', 'Postal Code': 33614, 'Region': 'South', 'Product ID': 'TEC-AC-10003832', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Logitech\xa0P710e Mobile Speakerphone', 'Sales': 617.976, 'Quantity': 3, 'Discount': 0.2, 'Profit': -7.7247}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f011'), 'Row ID': 245, 'Order ID': 'CA-2014-131926', 'Order Date': '6/1/2014', 'Ship Date': '6/6/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'DW-13480', 'Customer Name': 'Dianna Wilson', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Lakeville', 'State': 'Minnesota', 'Postal Code': 55044, 'Region': 'Central', 'Product ID': 'FUR-CH-10004063', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': "Global Deluxe High-Back Manager's Chair", 'Sales': 2001.86, 'Quantity': 7, 'Discount': 0.0, 'Profit': 580.5394}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f014'), 'Row ID': 248, 'Order ID': 'CA-2014-131926', 'Order Date': '6/1/2014', 'Ship Date': '6/6/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'DW-13480', 'Customer Name': 'Dianna Wilson', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Lakeville', 'State': 'Minnesota', 'Postal Code': 55044, 'Region': 'Central', 'Product ID': 'OFF-AP-10002945', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': "Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room", 'Sales': 1503.25, 'Quantity': 5, 'Discount': 0.0, 'Profit': 496.0725}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f018'), 'Row ID': 252, 'Order ID': 'CA-2016-145625', 'Order Date': '9/11/2016', 'Ship Date': '9/17/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'KC-16540', 'Customer Name': 'Kelly Collister', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Diego', 'State': 'California', 'Postal Code': 92037, 'Region': 'West', 'Product ID': 'TEC-AC-10003832', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Logitech\xa0P710e Mobile Speakerphone', 'Sales': 3347.37, 'Quantity': 13, 'Discount': 0.0, 'Profit': 636.0003}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f01e'), 'Row ID': 258, 'Order ID': 'US-2015-159982', 'Order Date': '11/28/2015', 'Ship Date': '12/4/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'DR-12880', 'Customer Name': 'Dan Reichenbach', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Chicago', 'State': 'Illinois', 'Postal Code': 60623, 'Region': 'Central', 'Product ID': 'TEC-PH-10001580', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Logitech Mobile Speakerphone P710e -\xa0speaker phone', 'Sales': 647.904, 'Quantity': 6, 'Discount': 0.2, 'Profit': 56.6916}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f023'), 'Row ID': 263, 'Order ID': 'US-2014-106992', 'Order Date': '9/19/2014', 'Ship Date': '9/21/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'SB-20290', 'Customer Name': 'Sean Braxton', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77036, 'Region': 'Central', 'Product ID': 'TEC-MA-10000822', 'Category': 'Technology', 'Sub-Category': 'Machines', 'Product Name': 'Lexmark MX611dhe Monochrome Laser Printer', 'Sales': 3059.982, 'Quantity': 3, 'Discount': 0.4, 'Profit': -509.997}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f024'), 'Row ID': 264, 'Order ID': 'US-2014-106992', 'Order Date': '9/19/2014', 'Ship Date': '9/21/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'SB-20290', 'Customer Name': 'Sean Braxton', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77036, 'Region': 'Central', 'Product ID': 'TEC-MA-10003353', 'Category': 'Technology', 'Sub-Category': 'Machines', 'Product Name': 'Xerox WorkCentre 6505DN Laser Multifunction Printer', 'Sales': 2519.958, 'Quantity': 7, 'Discount': 0.4, 'Profit': -251.9958}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f02b'), 'Row ID': 271, 'Order ID': 'CA-2017-163979', 'Order Date': '12/28/2017', 'Ship Date': '1/2/2018', 'Ship Mode': 'Second Class', 'Customer ID': 'KH-16690', 'Customer Name': 'Kristen Hastings', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94110, 'Region': 'West', 'Product ID': 'OFF-ST-10003208', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Adjustable Depth Letter/Legal Cart', 'Sales': 725.84, 'Quantity': 4, 'Discount': 0.0, 'Profit': 210.4936}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f036'), 'Row ID': 282, 'Order ID': 'US-2015-161991', 'Order Date': '9/26/2015', 'Ship Date': '9/28/2015', 'Ship Mode': 'Second Class', 'Customer ID': 'SC-20725', 'Customer Name': 'Steven Cartwright', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77070, 'Region': 'Central', 'Product ID': 'TEC-PH-10001760', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Bose SoundLink Bluetooth Speaker', 'Sales': 1114.4, 'Quantity': 7, 'Discount': 0.2, 'Profit': 376.11}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f037'), 'Row ID': 283, 'Order ID': 'CA-2015-130890', 'Order Date': '11/2/2015', 'Ship Date': '11/6/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'JO-15280', 'Customer Name': "Jas O'Carroll", 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90004, 'Region': 'West', 'Product ID': 'FUR-TA-10002903', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bevis Round Bullnose 29" High Table Top', 'Sales': 1038.84, 'Quantity': 5, 'Discount': 0.2, 'Profit': 51.942}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f03d'), 'Row ID': 289, 'Order ID': 'CA-2016-112697', 'Order Date': '12/18/2016', 'Ship Date': '12/20/2016', 'Ship Mode': 'Second Class', 'Customer ID': 'AH-10195', 'Customer Name': 'Alan Haines', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Tamarac', 'State': 'Florida', 'Postal Code': 33319, 'Region': 'South', 'Product ID': 'OFF-SU-10000646', 'Category': 'Office Supplies', 'Sub-Category': 'Supplies', 'Product Name': 'Premier Automatic Letter Opener', 'Sales': 961.48, 'Quantity': 5, 'Discount': 0.2, 'Profit': -204.3145}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f048'), 'Row ID': 300, 'Order ID': 'CA-2016-142545', 'Order Date': '10/28/2016', 'Ship Date': '11/3/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'JD-15895', 'Customer Name': 'Jonathan Doherty', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Belleville', 'State': 'New Jersey', 'Postal Code': 7109, 'Region': 'East', 'Product ID': 'OFF-ST-10002756', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Tennsco Stur-D-Stor Boltless Shelving, 5 Shelves, 24" Deep, Sand', 'Sales': 1082.48, 'Quantity': 8, 'Discount': 0.0, 'Profit': 10.8248}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f05b'), 'Row ID': 319, 'Order ID': 'CA-2014-164973', 'Order Date': '11/4/2014', 'Ship Date': '11/9/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'NM-18445', 'Customer Name': 'Nathan Mautz', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10024, 'Region': 'East', 'Product ID': 'TEC-MA-10002927', 'Category': 'Technology', 'Sub-Category': 'Machines', 'Product Name': 'Canon imageCLASS MF7460 Monochrome Digital Laser Multifunction Copier', 'Sales': 3991.98, 'Quantity': 2, 'Discount': 0.0, 'Profit': 1995.99}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f065'), 'Row ID': 329, 'Order ID': 'US-2016-141544', 'Order Date': '8/30/2016', 'Ship Date': '9/1/2016', 'Ship Mode': 'First Class', 'Customer ID': 'PO-18850', 'Customer Name': "Patrick O'Brill", 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19143, 'Region': 'East', 'Product ID': 'FUR-CH-10003312', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Hon 2090 \x93Pillow Soft\x94 Series Mid Back Swivel/Tilt Chairs', 'Sales': 786.744, 'Quantity': 4, 'Discount': 0.3, 'Profit': -258.5016}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f06c'), 'Row ID': 336, 'Order ID': 'CA-2015-137946', 'Order Date': '9/1/2015', 'Ship Date': '9/4/2015', 'Ship Mode': 'Second Class', 'Customer ID': 'DB-13615', 'Customer Name': 'Doug Bickford', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90045, 'Region': 'West', 'Product ID': 'TEC-CO-10001449', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Hewlett Packard LaserJet 3310 Copier', 'Sales': 959.984, 'Quantity': 2, 'Discount': 0.2, 'Profit': 335.9944}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f06f'), 'Row ID': 339, 'Order ID': 'CA-2014-129924', 'Order Date': '7/12/2014', 'Ship Date': '7/17/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'AC-10420', 'Customer Name': 'Alyssa Crouse', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94122, 'Region': 'West', 'Product ID': 'FUR-TA-10004575', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Hon 5100 Series Wood Tables', 'Sales': 698.352, 'Quantity': 3, 'Discount': 0.2, 'Profit': -17.4588}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f072'), 'Row ID': 342, 'Order ID': 'CA-2014-122336', 'Order Date': '4/13/2014', 'Ship Date': '4/17/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'JD-15895', 'Customer Name': 'Jonathan Doherty', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19140, 'Region': 'East', 'Product ID': 'OFF-BI-10003656', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Fellowes PB200 Plastic Comb Binding Machine', 'Sales': 509.97, 'Quantity': 10, 'Discount': 0.7, 'Profit': -407.976}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f07e'), 'Row ID': 354, 'Order ID': 'CA-2016-129714', 'Order Date': '9/1/2016', 'Ship Date': '9/3/2016', 'Ship Mode': 'First Class', 'Customer ID': 'AB-10060', 'Customer Name': 'Adam Bellavance', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10009, 'Region': 'East', 'Product ID': 'OFF-BI-10004995', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'GBC DocuBind P400 Electric Binding System', 'Sales': 4355.168, 'Quantity': 4, 'Discount': 0.2, 'Profit': 1415.4296}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f084'), 'Row ID': 360, 'Order ID': 'CA-2017-155698', 'Order Date': '3/8/2017', 'Ship Date': '3/11/2017', 'Ship Mode': 'First Class', 'Customer ID': 'VB-21745', 'Customer Name': 'Victoria Brennan', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Columbus', 'State': 'Georgia', 'Postal Code': 31907, 'Region': 'South', 'Product ID': 'OFF-AP-10001124', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': 'Belkin 8 Outlet SurgeMaster II Gold Surge Protector with Phone Protection', 'Sales': 647.84, 'Quantity': 8, 'Discount': 0.0, 'Profit': 168.4384}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f08e'), 'Row ID': 370, 'Order ID': 'CA-2016-155516', 'Order Date': '10/21/2016', 'Ship Date': '10/21/2016', 'Ship Mode': 'Same Day', 'Customer ID': 'MK-17905', 'Customer Name': 'Michael Kennedy', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Manchester', 'State': 'Connecticut', 'Postal Code': 6040, 'Region': 'East', 'Product ID': 'FUR-BO-10002545', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Atlantic Metals Mobile 3-Shelf Bookcases, Custom Colors', 'Sales': 1043.92, 'Quantity': 4, 'Discount': 0.0, 'Profit': 271.4192}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f092'), 'Row ID': 374, 'Order ID': 'US-2014-119137', 'Order Date': '7/23/2014', 'Ship Date': '7/27/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'AG-10900', 'Customer Name': 'Arthur Gainer', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Tucson', 'State': 'Arizona', 'Postal Code': 85705, 'Region': 'West', 'Product ID': 'TEC-AC-10003911', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'NETGEAR AC1750 Dual Band Gigabit\xa0Smart WiFi Router', 'Sales': 1023.936, 'Quantity': 8, 'Discount': 0.2, 'Profit': 179.1888}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f096'), 'Row ID': 378, 'Order ID': 'US-2017-134481', 'Order Date': '8/27/2017', 'Ship Date': '9/1/2017', 'Ship Mode': 'Standard Class', 'Customer ID': 'AR-10405', 'Customer Name': 'Allen Rosenblatt', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Franklin', 'State': 'Massachusetts', 'Postal Code': 2038, 'Region': 'East', 'Product ID': 'FUR-TA-10004915', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Office Impressions End Table, 20-1/2"H x 24"W x 20"D', 'Sales': 1488.424, 'Quantity': 7, 'Discount': 0.3, 'Profit': -297.6848}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0a5'), 'Row ID': 393, 'Order ID': 'US-2014-135972', 'Order Date': '9/21/2014', 'Ship Date': '9/23/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'JG-15115', 'Customer Name': 'Jack Garza', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Des Moines', 'State': 'Washington', 'Postal Code': 98198, 'Region': 'West', 'Product ID': 'TEC-CO-10002313', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Canon PC1080F Personal Copier', 'Sales': 1799.97, 'Quantity': 3, 'Discount': 0.0, 'Profit': 701.9883}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0ac'), 'Row ID': 400, 'Order ID': 'CA-2016-108987', 'Order Date': '9/8/2016', 'Ship Date': '9/10/2016', 'Ship Mode': 'Second Class', 'Customer ID': 'AG-10675', 'Customer Name': 'Anna Gayman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77036, 'Region': 'Central', 'Product ID': 'FUR-BO-10004834', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish', 'Sales': 2396.2656, 'Quantity': 4, 'Discount': 0.32, 'Profit': -317.1528}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0b3'), 'Row ID': 407, 'Order ID': 'CA-2017-117457', 'Order Date': '12/8/2017', 'Ship Date': '12/12/2017', 'Ship Mode': 'Standard Class', 'Customer ID': 'KH-16510', 'Customer Name': 'Keith Herrera', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94110, 'Region': 'West', 'Product ID': 'TEC-CO-10004115', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Sharp AL-1530CS Digital Copier', 'Sales': 1199.976, 'Quantity': 3, 'Discount': 0.2, 'Profit': 434.9913}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0b5'), 'Row ID': 409, 'Order ID': 'CA-2017-117457', 'Order Date': '12/8/2017', 'Ship Date': '12/12/2017', 'Ship Mode': 'Standard Class', 'Customer ID': 'KH-16510', 'Customer Name': 'Keith Herrera', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94110, 'Region': 'West', 'Product ID': 'FUR-TA-10002041', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bevis Round Conference Table Top, X-Base', 'Sales': 1004.024, 'Quantity': 7, 'Discount': 0.2, 'Profit': -112.9527}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0b9'), 'Row ID': 413, 'Order ID': 'CA-2017-117457', 'Order Date': '12/8/2017', 'Ship Date': '12/12/2017', 'Ship Mode': 'Standard Class', 'Customer ID': 'KH-16510', 'Customer Name': 'Keith Herrera', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94110, 'Region': 'West', 'Product ID': 'FUR-BO-10001972', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': "O'Sullivan 4-Shelf Bookcase in Odessa Pine", 'Sales': 1336.829, 'Quantity': 13, 'Discount': 0.15, 'Profit': 31.4548}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0c5'), 'Row ID': 425, 'Order ID': 'CA-2017-155705', 'Order Date': '8/21/2017', 'Ship Date': '8/23/2017', 'Ship Mode': 'Second Class', 'Customer ID': 'NF-18385', 'Customer Name': 'Natalie Fritzler', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Jackson', 'State': 'Mississippi', 'Postal Code': 39212, 'Region': 'South', 'Product ID': 'FUR-CH-10000015', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Hon Multipurpose Stacking Arm Chairs', 'Sales': 866.4, 'Quantity': 4, 'Discount': 0.0, 'Profit': 225.264}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0ce'), 'Row ID': 434, 'Order ID': 'CA-2016-127369', 'Order Date': '6/6/2016', 'Ship Date': '6/7/2016', 'Ship Mode': 'First Class', 'Customer ID': 'DB-13060', 'Customer Name': 'Dave Brooks', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Lowell', 'State': 'Massachusetts', 'Postal Code': 1852, 'Region': 'East', 'Product ID': 'OFF-ST-10003306', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Letter Size Cart', 'Sales': 714.3, 'Quantity': 5, 'Discount': 0.0, 'Profit': 207.147}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0d1'), 'Row ID': 437, 'Order ID': 'CA-2016-147375', 'Order Date': '6/12/2016', 'Ship Date': '6/14/2016', 'Ship Mode': 'Second Class', 'Customer ID': 'PO-19180', 'Customer Name': 'Philisse Overcash', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Chicago', 'State': 'Illinois', 'Postal Code': 60623, 'Region': 'Central', 'Product ID': 'TEC-MA-10002937', 'Category': 'Technology', 'Sub-Category': 'Machines', 'Product Name': 'Canon Color ImageCLASS MF8580Cdw Wireless Laser All-In-One Printer, Copier, Scanner', 'Sales': 1007.979, 'Quantity': 3, 'Discount': 0.3, 'Profit': 43.1991}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0e3'), 'Row ID': 455, 'Order ID': 'CA-2017-147277', 'Order Date': '10/20/2017', 'Ship Date': '10/24/2017', 'Ship Mode': 'Standard Class', 'Customer ID': 'EB-13705', 'Customer Name': 'Ed Braxton', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Akron', 'State': 'Ohio', 'Postal Code': 44312, 'Region': 'East', 'Product ID': 'OFF-ST-10000142', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Deluxe Rollaway Locking File with Drawer', 'Sales': 665.408, 'Quantity': 2, 'Discount': 0.2, 'Profit': 66.5408}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0e6'), 'Row ID': 458, 'Order ID': 'US-2016-157945', 'Order Date': '9/26/2016', 'Ship Date': '10/1/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'NF-18385', 'Customer Name': 'Natalie Fritzler', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Decatur', 'State': 'Illinois', 'Postal Code': 62521, 'Region': 'Central', 'Product ID': 'FUR-CH-10002331', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Hon 4700 Series Mobuis Mid-Back Task Chairs with Adjustable Arms', 'Sales': 747.558, 'Quantity': 3, 'Discount': 0.3, 'Profit': -96.1146}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0e9'), 'Row ID': 461, 'Order ID': 'CA-2015-109638', 'Order Date': '12/15/2015', 'Ship Date': '12/22/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'JH-15985', 'Customer Name': 'Joseph Holt', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal Code': 98115, 'Region': 'West', 'Product ID': 'TEC-AC-10004571', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Logitech G700s Rechargeable Gaming Mouse', 'Sales': 899.91, 'Quantity': 9, 'Discount': 0.0, 'Profit': 377.9622}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0ec'), 'Row ID': 464, 'Order ID': 'CA-2016-109869', 'Order Date': '4/22/2016', 'Ship Date': '4/29/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'TN-21040', 'Customer Name': 'Tanja Norvell', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Phoenix', 'State': 'Arizona', 'Postal Code': 85023, 'Region': 'West', 'Product ID': 'FUR-TA-10001889', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bush Advantage Collection Racetrack Conference Table', 'Sales': 1272.63, 'Quantity': 6, 'Discount': 0.5, 'Profit': -814.4832}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0f6'), 'Row ID': 474, 'Order ID': 'CA-2014-144666', 'Order Date': '11/9/2014', 'Ship Date': '11/11/2014', 'Ship Mode': 'Second Class', 'Customer ID': 'JP-15520', 'Customer Name': 'Jeremy Pistek', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94110, 'Region': 'West', 'Product ID': 'TEC-PH-10002680', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Samsung Galaxy Note 3', 'Sales': 703.968, 'Quantity': 4, 'Discount': 0.2, 'Profit': 87.996}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f0fd'), 'Row ID': 481, 'Order ID': 'CA-2016-100790', 'Order Date': '6/26/2016', 'Ship Date': '7/2/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'JG-15805', 'Customer Name': 'John Grady', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10024, 'Region': 'East', 'Product ID': 'OFF-ST-10000689', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Fellowes Strictly Business Drawer File, Letter/Legal Size', 'Sales': 704.25, 'Quantity': 5, 'Discount': 0.0, 'Profit': 84.51}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f102'), 'Row ID': 486, 'Order ID': 'CA-2017-140963', 'Order Date': '6/10/2017', 'Ship Date': '6/13/2017', 'Ship Mode': 'First Class', 'Customer ID': 'MT-18070', 'Customer Name': 'Michelle Tran', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90045, 'Region': 'West', 'Product ID': 'FUR-BO-10001337', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': "O'Sullivan Living Dimensions 2-Shelf Bookcases", 'Sales': 514.165, 'Quantity': 5, 'Discount': 0.15, 'Profit': -30.245}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f104'), 'Row ID': 488, 'Order ID': 'CA-2014-154627', 'Order Date': '10/29/2014', 'Ship Date': '10/31/2014', 'Ship Mode': 'First Class', 'Customer ID': 'SA-20830', 'Customer Name': 'Sue Ann Reed', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Chicago', 'State': 'Illinois', 'Postal Code': 60610, 'Region': 'Central', 'Product ID': 'TEC-PH-10001363', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Apple iPhone 5S', 'Sales': 2735.952, 'Quantity': 6, 'Discount': 0.2, 'Profit': 341.994}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f113'), 'Row ID': 503, 'Order ID': 'US-2016-105578', 'Order Date': '5/30/2016', 'Ship Date': '6/4/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'MY-17380', 'Customer Name': 'Maribeth Yedwab', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Parker', 'State': 'Colorado', 'Postal Code': 80134, 'Region': 'West', 'Product ID': 'FUR-CH-10001215', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Global Troy Executive Leather Low-Back Tilter', 'Sales': 801.568, 'Quantity': 2, 'Discount': 0.2, 'Profit': 50.098}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f11a'), 'Row ID': 510, 'Order ID': 'CA-2015-145352', 'Order Date': '3/16/2015', 'Ship Date': '3/22/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'CM-12385', 'Customer Name': 'Christopher Martinez', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Atlanta', 'State': 'Georgia', 'Postal Code': 30318, 'Region': 'South', 'Product ID': 'OFF-BI-10003527', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind', 'Sales': 6354.95, 'Quantity': 5, 'Discount': 0.0, 'Profit': 3177.475}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f120'), 'Row ID': 516, 'Order ID': 'CA-2017-127432', 'Order Date': '1/22/2017', 'Ship Date': '1/27/2017', 'Ship Mode': 'Standard Class', 'Customer ID': 'AD-10180', 'Customer Name': 'Alan Dominguez', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Great Falls', 'State': 'Montana', 'Postal Code': 59405, 'Region': 'West', 'Product ID': 'TEC-CO-10003236', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Canon Image Class D660 Copier', 'Sales': 2999.95, 'Quantity': 5, 'Discount': 0.0, 'Profit': 1379.977}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f123'), 'Row ID': 519, 'Order ID': 'CA-2017-127432', 'Order Date': '1/22/2017', 'Ship Date': '1/27/2017', 'Ship Mode': 'Standard Class', 'Customer ID': 'AD-10180', 'Customer Name': 'Alan Dominguez', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Great Falls', 'State': 'Montana', 'Postal Code': 59405, 'Region': 'West', 'Product ID': 'OFF-ST-10004459', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Tennsco Single-Tier Lockers', 'Sales': 1126.02, 'Quantity': 3, 'Discount': 0.0, 'Profit': 56.301}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f12b'), 'Row ID': 527, 'Order ID': 'CA-2017-113558', 'Order Date': '10/21/2017', 'Ship Date': '10/26/2017', 'Ship Mode': 'Standard Class', 'Customer ID': 'PH-18790', 'Customer Name': 'Patricia Hirasaki', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Lakeland', 'State': 'Florida', 'Postal Code': 33801, 'Region': 'South', 'Product ID': 'FUR-CH-10003379', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Global Commerce Series High-Back Swivel/Tilt Chairs', 'Sales': 683.952, 'Quantity': 3, 'Discount': 0.2, 'Profit': 42.747}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f12e'), 'Row ID': 530, 'Order ID': 'US-2015-138303', 'Order Date': '9/3/2015', 'Ship Date': '9/7/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'MG-18145', 'Customer Name': 'Mike Gockenbach', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19134, 'Region': 'East', 'Product ID': 'OFF-SU-10002881', 'Category': 'Office Supplies', 'Sub-Category': 'Supplies', 'Product Name': 'Martin Yale Chadless Opener Electric Letter Opener', 'Sales': 666.248, 'Quantity': 1, 'Discount': 0.2, 'Profit': -149.9058}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f132'), 'Row ID': 534, 'Order ID': 'CA-2016-168753', 'Order Date': '5/29/2016', 'Ship Date': '6/1/2016', 'Ship Mode': 'Second Class', 'Customer ID': 'RL-19615', 'Customer Name': 'Rob Lucas', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Montgomery', 'State': 'Alabama', 'Postal Code': 36116, 'Region': 'South', 'Product ID': 'TEC-PH-10000984', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Panasonic KX-TG9471B', 'Sales': 979.95, 'Quantity': 5, 'Discount': 0.0, 'Profit': 274.386}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f13b'), 'Row ID': 543, 'Order ID': 'US-2015-120161', 'Order Date': '12/18/2015', 'Ship Date': '12/23/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'LM-17065', 'Customer Name': 'Liz MacKendrick', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Springfield', 'State': 'Ohio', 'Postal Code': 45503, 'Region': 'East', 'Product ID': 'OFF-ST-10001809', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Fellowes Officeware Wire Shelving', 'Sales': 646.776, 'Quantity': 9, 'Discount': 0.2, 'Profit': -145.5246}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f144'), 'Row ID': 552, 'Order ID': 'CA-2016-136406', 'Order Date': '4/15/2016', 'Ship Date': '4/17/2016', 'Ship Mode': 'Second Class', 'Customer ID': 'BD-11320', 'Customer Name': 'Bill Donatelli', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94110, 'Region': 'West', 'Product ID': 'FUR-CH-10002024', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'HON 5400 Series Task Chairs for Big and Tall', 'Sales': 1121.568, 'Quantity': 2, 'Discount': 0.2, 'Profit': 0.0}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f147'), 'Row ID': 555, 'Order ID': 'CA-2017-100650', 'Order Date': '6/29/2017', 'Ship Date': '7/3/2017', 'Ship Mode': 'Second Class', 'Customer ID': 'DK-13225', 'Customer Name': 'Dean Katz', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Anaheim', 'State': 'California', 'Postal Code': 92804, 'Region': 'West', 'Product ID': 'OFF-ST-10001780', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Tennsco 16-Compartment Lockers with Coat Rack', 'Sales': 1295.78, 'Quantity': 2, 'Discount': 0.0, 'Profit': 310.9872}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f14a'), 'Row ID': 558, 'Order ID': 'CA-2016-113243', 'Order Date': '6/10/2016', 'Ship Date': '6/15/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'OT-18730', 'Customer Name': 'Olvera Toch', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90045, 'Region': 'West', 'Product ID': 'FUR-TA-10004256', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bretford \x93Just In Time\x94 Height-Adjustable Multi-Task Work Tables', 'Sales': 1335.68, 'Quantity': 4, 'Discount': 0.2, 'Profit': -217.048}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f170'), 'Row ID': 596, 'Order ID': 'CA-2014-131450', 'Order Date': '8/8/2014', 'Ship Date': '8/15/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'LR-16915', 'Customer Name': 'Lena Radford', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Diego', 'State': 'California', 'Postal Code': 92024, 'Region': 'West', 'Product ID': 'TEC-CO-10004115', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Sharp AL-1530CS Digital Copier', 'Sales': 1199.976, 'Quantity': 3, 'Discount': 0.2, 'Profit': 434.9913}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f182'), 'Row ID': 614, 'Order ID': 'CA-2016-121223', 'Order Date': '9/11/2016', 'Ship Date': '9/13/2016', 'Ship Mode': 'Second Class', 'Customer ID': 'GD-14590', 'Customer Name': 'Giulietta Dortch', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Postal Code': 19143, 'Region': 'East', 'Product ID': 'TEC-PH-10004667', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'Cisco 8x8 Inc. 6753i IP Business Phone System', 'Sales': 728.946, 'Quantity': 9, 'Discount': 0.4, 'Profit': -157.9383}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f18c'), 'Row ID': 624, 'Order ID': 'CA-2015-138009', 'Order Date': '11/29/2015', 'Ship Date': '12/3/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'SF-20965', 'Customer Name': 'Sylvia Foulston', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Dearborn', 'State': 'Michigan', 'Postal Code': 48126, 'Region': 'Central', 'Product ID': 'OFF-AP-10000179', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': 'Honeywell Enviracaire Portable HEPA Air Cleaner for up to 10 x 16 Room', 'Sales': 555.21, 'Quantity': 5, 'Discount': 0.1, 'Profit': 178.901}
# {'_id': ObjectId('67abb13f3bb89c39c0c8f18d'), 'Row ID': 625, 'Order ID': 'CA-2015-138009', 'Order Date': '11/29/2015', 'Ship Date': '12/3/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'SF-20965', 'Customer Name': 'Sylvia Foulston', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Dearborn', 'State': 'Michigan', 'Postal Code': 48126, 'Region': 'Central', 'Product ID': 'OFF-ST-10001272', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Mini 13-1/2 Capacity Data Binder Rack, Pearl', 'Sales': 523.48, 'Quantity': 4, 'Discount': 0.0, 'Profit': 130.87}
# ...
# {'_id': ObjectId('67abb1923bb89c39c0c93c28'), 'Row ID': 9728, 'Order ID': 'CA-2017-167395', 'Order Date': '12/2/2017', 'Ship Date': '12/4/2017', 'Ship Mode': 'First Class', 'Customer ID': 'KM-16720', 'Customer Name': 'Kunst Miller', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Lowell', 'State': 'Massachusetts', 'Postal Code': 1852, 'Region': 'East', 'Product ID': 'TEC-PH-10004977', 'Category': 'Technology', 'Sub-Category': 'Phones', 'Product Name': 'GE 30524EE4', 'Sales': 979.95, 'Quantity': 5, 'Discount': 0.0, 'Profit': 284.1855}
# {'_id': ObjectId('67abb1923bb89c39c0c93c2b'), 'Row ID': 9731, 'Order ID': 'CA-2014-111962', 'Order Date': '9/29/2014', 'Ship Date': '10/4/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'EB-14170', 'Customer Name': 'Evan Bailliet', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal Code': 98115, 'Region': 'West', 'Product ID': 'OFF-ST-10000046', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Fellowes Super Stor/Drawer Files', 'Sales': 807.75, 'Quantity': 5, 'Discount': 0.0, 'Profit': 153.4725}
# {'_id': ObjectId('67abb1923bb89c39c0c93c2d'), 'Row ID': 9733, 'Order ID': 'CA-2014-114321', 'Order Date': '8/20/2014', 'Ship Date': '8/25/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'NC-18535', 'Customer Name': 'Nick Crebassa', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Hampton', 'State': 'Virginia', 'Postal Code': 23666, 'Region': 'South', 'Product ID': 'FUR-CH-10001797', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Safco Chair Connectors, 6/Carton', 'Sales': 500.24, 'Quantity': 13, 'Discount': 0.0, 'Profit': 145.0696}
# {'_id': ObjectId('67abb1923bb89c39c0c93c2f'), 'Row ID': 9735, 'Order ID': 'CA-2014-114321', 'Order Date': '8/20/2014', 'Ship Date': '8/25/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'NC-18535', 'Customer Name': 'Nick Crebassa', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Hampton', 'State': 'Virginia', 'Postal Code': 23666, 'Region': 'South', 'Product ID': 'OFF-BI-10001359', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'GBC DocuBind TL300 Electric Binding System', 'Sales': 896.99, 'Quantity': 1, 'Discount': 0.0, 'Profit': 421.5853}
# {'_id': ObjectId('67abb1923bb89c39c0c93c36'), 'Row ID': 9742, 'Order ID': 'CA-2015-117086', 'Order Date': '11/8/2015', 'Ship Date': '11/12/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'QJ-19255', 'Customer Name': 'Quincy Jones', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Burlington', 'State': 'Vermont', 'Postal Code': 5408, 'Region': 'East', 'Product ID': 'FUR-BO-10004834', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish', 'Sales': 4404.9, 'Quantity': 5, 'Discount': 0.0, 'Profit': 1013.127}
# {'_id': ObjectId('67abb1923bb89c39c0c93c3d'), 'Row ID': 9749, 'Order ID': 'US-2014-140914', 'Order Date': '11/11/2014', 'Ship Date': '11/15/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'BH-11710', 'Customer Name': 'Brosina Hoffman', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Chicago', 'State': 'Illinois', 'Postal Code': 60653, 'Region': 'Central', 'Product ID': 'FUR-CH-10003379', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Global Commerce Series High-Back Swivel/Tilt Chairs', 'Sales': 797.944, 'Quantity': 4, 'Discount': 0.3, 'Profit': -56.996}
# {'_id': ObjectId('67abb1923bb89c39c0c93c48'), 'Row ID': 9760, 'Order ID': 'CA-2016-146913', 'Order Date': '10/31/2016', 'Ship Date': '11/5/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'SF-20965', 'Customer Name': 'Sylvia Foulston', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94109, 'Region': 'West', 'Product ID': 'FUR-CH-10001854', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Office Star - Professional Matrix Back Chair with 2-to-1 Synchro Tilt and Mesh Fabric Seat', 'Sales': 1403.92, 'Quantity': 5, 'Discount': 0.2, 'Profit': 70.196}
# {'_id': ObjectId('67abb1923bb89c39c0c93c57'), 'Row ID': 9775, 'Order ID': 'CA-2014-169019', 'Order Date': '7/26/2014', 'Ship Date': '7/30/2014', 'Ship Mode': 'Standard Class', 'Customer ID': 'LF-17185', 'Customer Name': 'Luke Foster', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Antonio', 'State': 'Texas', 'Postal Code': 78207, 'Region': 'Central', 'Product ID': 'OFF-BI-10004995', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'GBC DocuBind P400 Electric Binding System', 'Sales': 2177.584, 'Quantity': 8, 'Discount': 0.8, 'Profit': -3701.8928}
# {'_id': ObjectId('67abb1923bb89c39c0c93c5e'), 'Row ID': 9782, 'Order ID': 'CA-2016-153178', 'Order Date': '9/14/2016', 'Ship Date': '9/18/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'CL-12565', 'Customer Name': 'Clay Ludtke', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Long Beach', 'State': 'New York', 'Postal Code': 11561, 'Region': 'East', 'Product ID': 'OFF-BI-10004390', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'GBC DocuBind 200 Manual Binding Machine', 'Sales': 673.568, 'Quantity': 2, 'Discount': 0.2, 'Profit': 252.588}
# {'_id': ObjectId('67abb1923bb89c39c0c93c64'), 'Row ID': 9788, 'Order ID': 'CA-2017-144491', 'Order Date': '3/27/2017', 'Ship Date': '4/1/2017', 'Ship Mode': 'Standard Class', 'Customer ID': 'CJ-12010', 'Customer Name': 'Caroline Jumper', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77070, 'Region': 'Central', 'Product ID': 'FUR-BO-10001811', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Atlantic Metals Mobile 5-Shelf Bookcases, Custom Colors', 'Sales': 1023.332, 'Quantity': 5, 'Discount': 0.32, 'Profit': -30.098}
# {'_id': ObjectId('67abb1923bb89c39c0c93c65'), 'Row ID': 9789, 'Order ID': 'CA-2017-144491', 'Order Date': '3/27/2017', 'Ship Date': '4/1/2017', 'Ship Mode': 'Standard Class', 'Customer ID': 'CJ-12010', 'Customer Name': 'Caroline Jumper', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Houston', 'State': 'Texas', 'Postal Code': 77070, 'Region': 'Central', 'Product ID': 'FUR-CH-10004063', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': "Global Deluxe High-Back Manager's Chair", 'Sales': 600.558, 'Quantity': 3, 'Discount': 0.3, 'Profit': -8.5794}
# {'_id': ObjectId('67abb1923bb89c39c0c93c81'), 'Row ID': 9817, 'Order ID': 'CA-2015-162201', 'Order Date': '6/8/2015', 'Ship Date': '6/12/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'AG-10495', 'Customer Name': 'Andrew Gjertsen', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Saint Petersburg', 'State': 'Florida', 'Postal Code': 33710, 'Region': 'South', 'Product ID': 'OFF-ST-10000046', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Fellowes Super Stor/Drawer Files', 'Sales': 516.96, 'Quantity': 4, 'Discount': 0.2, 'Profit': -6.462}
# {'_id': ObjectId('67abb1923bb89c39c0c93c92'), 'Row ID': 9834, 'Order ID': 'CA-2017-130302', 'Order Date': '9/14/2017', 'Ship Date': '9/19/2017', 'Ship Mode': 'Standard Class', 'Customer ID': 'CY-12745', 'Customer Name': 'Craig Yedwab', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Springfield', 'State': 'Ohio', 'Postal Code': 45503, 'Region': 'East', 'Product ID': 'TEC-AC-10002001', 'Category': 'Technology', 'Sub-Category': 'Accessories', 'Product Name': 'Logitech Wireless Gaming Headset G930', 'Sales': 895.944, 'Quantity': 7, 'Discount': 0.2, 'Profit': 190.3881}
# {'_id': ObjectId('67abb1923bb89c39c0c93ca0'), 'Row ID': 9848, 'Order ID': 'CA-2017-169327', 'Order Date': '9/2/2017', 'Ship Date': '9/4/2017', 'Ship Mode': 'Second Class', 'Customer ID': 'MH-17290', 'Customer Name': 'Marc Harrigan', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Los Angeles', 'State': 'California', 'Postal Code': 90008, 'Region': 'West', 'Product ID': 'FUR-FU-10004188', 'Category': 'Furniture', 'Sub-Category': 'Furnishings', 'Product Name': 'Luxo Professional Combination Clamp-On Lamps', 'Sales': 511.5, 'Quantity': 5, 'Discount': 0.0, 'Profit': 132.99}
# {'_id': ObjectId('67abb1923bb89c39c0c93caa'), 'Row ID': 9858, 'Order ID': 'CA-2015-164301', 'Order Date': '3/26/2015', 'Ship Date': '3/30/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'EB-13840', 'Customer Name': 'Ellis Ballard', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal Code': 98103, 'Region': 'West', 'Product ID': 'FUR-TA-10001889', 'Category': 'Furniture', 'Sub-Category': 'Tables', 'Product Name': 'Bush Advantage Collection Racetrack Conference Table', 'Sales': 3393.68, 'Quantity': 8, 'Discount': 0.0, 'Profit': 610.8624}
# {'_id': ObjectId('67abb1923bb89c39c0c93cb3'), 'Row ID': 9867, 'Order ID': 'US-2015-116981', 'Order Date': '3/26/2015', 'Ship Date': '3/28/2015', 'Ship Mode': 'Second Class', 'Customer ID': 'SM-20950', 'Customer Name': 'Suzanne McNair', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10009, 'Region': 'East', 'Product ID': 'OFF-ST-10002615', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Dual Level, Single-Width Filing Carts', 'Sales': 1085.42, 'Quantity': 7, 'Discount': 0.0, 'Profit': 282.2092}
# {'_id': ObjectId('67abb1923bb89c39c0c93cbd'), 'Row ID': 9877, 'Order ID': 'US-2017-166324', 'Order Date': '4/20/2017', 'Ship Date': '4/21/2017', 'Ship Mode': 'First Class', 'Customer ID': 'BE-11455', 'Customer Name': 'Brad Eason', 'Segment': 'Home Office', 'Country': 'United States', 'City': 'Cleveland', 'State': 'Ohio', 'Postal Code': 44105, 'Region': 'East', 'Product ID': 'OFF-ST-10000078', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Tennsco 6- and 18-Compartment Lockers', 'Sales': 848.544, 'Quantity': 4, 'Discount': 0.2, 'Profit': -21.2136}
# {'_id': ObjectId('67abb1923bb89c39c0c93cc0'), 'Row ID': 9880, 'Order ID': 'CA-2016-122581', 'Order Date': '8/21/2016', 'Ship Date': '8/25/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'JK-15370', 'Customer Name': 'Jay Kimmel', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10035, 'Region': 'East', 'Product ID': 'FUR-CH-10002961', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Leather Task Chair, Black', 'Sales': 573.174, 'Quantity': 7, 'Discount': 0.1, 'Profit': 63.686}
# {'_id': ObjectId('67abb1923bb89c39c0c93cdc'), 'Row ID': 9908, 'Order ID': 'US-2015-129007', 'Order Date': '9/13/2015', 'Ship Date': '9/15/2015', 'Ship Mode': 'First Class', 'Customer ID': 'KD-16615', 'Customer Name': 'Ken Dana', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Anaheim', 'State': 'California', 'Postal Code': 92804, 'Region': 'West', 'Product ID': 'FUR-CH-10000155', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Global Comet Stacking Armless Chair', 'Sales': 717.72, 'Quantity': 3, 'Discount': 0.2, 'Profit': 71.772}
# {'_id': ObjectId('67abb1923bb89c39c0c93ce8'), 'Row ID': 9920, 'Order ID': 'CA-2016-149272', 'Order Date': '3/15/2016', 'Ship Date': '3/19/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'MY-18295', 'Customer Name': 'Muhammed Yedwab', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Bryan', 'State': 'Texas', 'Postal Code': 77803, 'Region': 'Central', 'Product ID': 'FUR-CH-10000863', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Novimex Swivel Fabric Task Chair', 'Sales': 528.43, 'Quantity': 5, 'Discount': 0.3, 'Profit': -143.431}
# {'_id': ObjectId('67abb1923bb89c39c0c93cee'), 'Row ID': 9926, 'Order ID': 'CA-2015-159534', 'Order Date': '3/20/2015', 'Ship Date': '3/23/2015', 'Ship Mode': 'First Class', 'Customer ID': 'DH-13075', 'Customer Name': 'Dave Hallsten', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'New York City', 'State': 'New York', 'Postal Code': 10035, 'Region': 'East', 'Product ID': 'OFF-BI-10003656', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Fellowes PB200 Plastic Comb Binding Machine', 'Sales': 1087.936, 'Quantity': 8, 'Discount': 0.2, 'Profit': 353.5792}
# {'_id': ObjectId('67abb1923bb89c39c0c93cf2'), 'Row ID': 9930, 'Order ID': 'CA-2016-129630', 'Order Date': '9/4/2016', 'Ship Date': '9/4/2016', 'Ship Mode': 'Same Day', 'Customer ID': 'IM-15055', 'Customer Name': 'Ionia McGrath', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Francisco', 'State': 'California', 'Postal Code': 94122, 'Region': 'West', 'Product ID': 'TEC-CO-10003763', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Canon PC1060 Personal Laser Copier', 'Sales': 2799.96, 'Quantity': 5, 'Discount': 0.2, 'Profit': 944.9865}
# {'_id': ObjectId('67abb1923bb89c39c0c93cf4'), 'Row ID': 9932, 'Order ID': 'CA-2015-104948', 'Order Date': '11/13/2015', 'Ship Date': '11/17/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'KH-16510', 'Customer Name': 'Keith Herrera', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'San Bernardino', 'State': 'California', 'Postal Code': 92404, 'Region': 'West', 'Product ID': 'FUR-BO-10004357', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': "O'Sullivan Living Dimensions 3-Shelf Bookcases", 'Sales': 683.332, 'Quantity': 4, 'Discount': 0.15, 'Profit': -40.196}
# {'_id': ObjectId('67abb1923bb89c39c0c93cff'), 'Row ID': 9943, 'Order ID': 'CA-2014-143371', 'Order Date': '12/28/2014', 'Ship Date': '1/3/2015', 'Ship Mode': 'Standard Class', 'Customer ID': 'MD-17350', 'Customer Name': 'Maribeth Dona', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Anaheim', 'State': 'California', 'Postal Code': 92804, 'Region': 'West', 'Product ID': 'OFF-ST-10001128', 'Category': 'Office Supplies', 'Sub-Category': 'Storage', 'Product Name': 'Carina Mini System Audio Rack, Model AR050B', 'Sales': 998.82, 'Quantity': 9, 'Discount': 0.0, 'Profit': 29.9646}
# {'_id': ObjectId('67abb1923bb89c39c0c93d04'), 'Row ID': 9948, 'Order ID': 'CA-2017-121559', 'Order Date': '6/1/2017', 'Ship Date': '6/3/2017', 'Ship Mode': 'Second Class', 'Customer ID': 'HW-14935', 'Customer Name': 'Helen Wasserman', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Indianapolis', 'State': 'Indiana', 'Postal Code': 46203, 'Region': 'Central', 'Product ID': 'FUR-CH-10003746', 'Category': 'Furniture', 'Sub-Category': 'Chairs', 'Product Name': 'Hon 4070 Series Pagoda Round Back Stacking Chairs', 'Sales': 1925.88, 'Quantity': 6, 'Discount': 0.0, 'Profit': 539.2464}
# {'_id': ObjectId('67abb1923bb89c39c0c93d05'), 'Row ID': 9949, 'Order ID': 'CA-2017-121559', 'Order Date': '6/1/2017', 'Ship Date': '6/3/2017', 'Ship Mode': 'Second Class', 'Customer ID': 'HW-14935', 'Customer Name': 'Helen Wasserman', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Indianapolis', 'State': 'Indiana', 'Postal Code': 46203, 'Region': 'Central', 'Product ID': 'OFF-AP-10002945', 'Category': 'Office Supplies', 'Sub-Category': 'Appliances', 'Product Name': "Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room", 'Sales': 2405.2, 'Quantity': 8, 'Discount': 0.0, 'Profit': 793.716}
# {'_id': ObjectId('67abb1923bb89c39c0c93d19'), 'Row ID': 9969, 'Order ID': 'CA-2017-153871', 'Order Date': '12/11/2017', 'Ship Date': '12/17/2017', 'Ship Mode': 'Standard Class', 'Customer ID': 'RB-19435', 'Customer Name': 'Richard Bierner', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Plainfield', 'State': 'New Jersey', 'Postal Code': 7060, 'Region': 'East', 'Product ID': 'OFF-BI-10004600', 'Category': 'Office Supplies', 'Sub-Category': 'Binders', 'Product Name': 'Ibico Ibimaster 300 Manual Binding System', 'Sales': 735.98, 'Quantity': 2, 'Discount': 0.0, 'Profit': 331.191}

# %% [markdown]
# ## 6) Fetch the top 3 orders with the highest Profit

# %%
top_profit_orders = orders_collection.find().sort("Profit", -1).limit(3)

print("Top 3 Orders with Highest Profit:")
for order in top_profit_orders:
    print(order)
# Out:
# Top 3 Orders with Highest Profit:
# {'_id': ObjectId('67abb1923bb89c39c0c930d3'), 'Row ID': 6827, 'Order ID': 'CA-2016-118689', 'Order Date': '10/2/2016', 'Ship Date': '10/9/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'TC-20980', 'Customer Name': 'Tamara Chand', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Lafayette', 'State': 'Indiana', 'Postal Code': 47905, 'Region': 'Central', 'Product ID': 'TEC-CO-10004722', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Canon imageCLASS 2200 Advanced Copier', 'Sales': 17499.95, 'Quantity': 5, 'Discount': 0.0, 'Profit': 8399.976}
# {'_id': ObjectId('67abb13f3bb89c39c0c909c7'), 'Row ID': 6827, 'Order ID': 'CA-2016-118689', 'Order Date': '10/2/2016', 'Ship Date': '10/9/2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'TC-20980', 'Customer Name': 'Tamara Chand', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Lafayette', 'State': 'Indiana', 'Postal Code': 47905, 'Region': 'Central', 'Product ID': 'TEC-CO-10004722', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Canon imageCLASS 2200 Advanced Copier', 'Sales': 17499.95, 'Quantity': 5, 'Discount': 0.0, 'Profit': 8399.976}
# {'_id': ObjectId('67abb13f3bb89c39c0c90ef6'), 'Row ID': 8154, 'Order ID': 'CA-2017-140151', 'Order Date': '3/23/2017', 'Ship Date': '3/25/2017', 'Ship Mode': 'First Class', 'Customer ID': 'RB-19360', 'Customer Name': 'Raymond Buch', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal Code': 98115, 'Region': 'West', 'Product ID': 'TEC-CO-10004722', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Canon imageCLASS 2200 Advanced Copier', 'Sales': 13999.96, 'Quantity': 4, 'Discount': 0.0, 'Profit': 6719.9808}

# %% [markdown]
# ## 7) Update all orders with Ship Mode as "First Class" to "Premium Class"

# %%
update_result = orders_collection.update_many(
    {"Ship Mode": "First Class"},
    {"$set": {"Ship Mode": "Premium Class"}}
)

print(f"\nUpdated {update_result.modified_count} orders where Ship Mode was 'First Class'.")
# Out:
# Updated 3076 orders where Ship Mode was 'First Class'.

# %% [markdown]
# ## 8) Delete all orders where Sales is less than 50

# %%
delete_result = orders_collection.delete_many({"Sales": {"$lt": 50}})

print(f"\nDeleted {delete_result.deleted_count} orders with Sales less than 50.")
# Out:
# Deleted 9698 orders with Sales less than 50.

# %% [markdown]
# ## 9) Use aggregation to group orders by Region and calculate total sales per region

# %%
region_sales = orders_collection.aggregate([
    {"$group": {"_id": "$Region", "total_sales": {"$sum": "$Sales"}}}
])

print("\nTotal Sales per Region:")
for region in region_sales:
    print(region)
# Out:
# Total Sales per Region:
# {'_id': 'East', 'total_sales': 1302275.41}
# {'_id': 'Central', 'total_sales': 959223.6916}
# {'_id': 'South', 'total_sales': 752046.624}
# {'_id': 'West', 'total_sales': 1389373.239}

# %% [markdown]
# ## 10) Fetch all distinct values for Ship Mode from the collection

# %%
distinct_ship_modes = orders_collection.distinct("Ship Mode")

print("\nDistinct Ship Modes:")
for ship_mode in distinct_ship_modes:
    print(ship_mode)
# Out:
# Distinct Ship Modes:
# Premium Class
# Same Day
# Second Class
# Standard Class

# %% [markdown]
# ## 11) Count the number of orders for each category (assuming Category field exists)

# %%
category_count = orders_collection.aggregate([
    {"$group": {"_id": "$Category", "order_count": {"$sum": 1}}}
])

print("\nNumber of Orders per Category:")
for category in category_count:
    print(category)
# Out:
# Number of Orders per Category:
# {'_id': 'Furniture', 'order_count': 3146}
# {'_id': 'Technology', 'order_count': 2992}
# {'_id': 'Office Supplies', 'order_count': 4152}
